# %% [markdown]
# ### Feature

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda install -c rdkit rdkit

# %%
from rdkit import Chem
from rdkit.Chem import rdchem
# from rdkit.Chem import AllChem
import re

Chiral = {"CHI_UNSPECIFIED": 0, "CHI_TETRAHEDRAL_CW": 1, "CHI_TETRAHEDRAL_CCW": 2, "CHI_OTHER": 3}
Hybridization = {"UNSPECIFIED": 0, "S": 1, "SP": 2, "SP2": 3, "SP3": 4, "SP3D": 5, "SP3D2": 6, "OTHER": 7}

# feature vector
atomInfo = 21
structInfo = 21
lensize = atomInfo + structInfo

H_Vector = [0] * atomInfo
H_Vector[0] = 1

lowerReg = re.compile(r'^[a-z]+$')

def islower(s):
    return lowerReg.match(s) is not None

upperReg = re.compile(r'^[A-Z]+$')

def isupper(s):
    return upperReg.match(s) is not None

def calc_atom_feature(atom):
    if atom.GetSymbol() == 'H':
        feature = [1, 0, 0, 0, 0]
    elif atom.GetSymbol() == 'C':
        feature = [0, 1, 0, 0, 0]
    elif atom.GetSymbol() == 'O':
        feature = [0, 0, 1, 0, 0]
    elif atom.GetSymbol() == 'N':
        feature = [0, 0, 0, 1, 0]
    else:
        feature = [0, 0, 0, 0, 1]

    feature.append(atom.GetTotalNumHs() / 8)
    feature.append(atom.GetTotalDegree() / 4)
    feature.append(atom.GetFormalCharge() / 8)
    feature.append(atom.GetTotalValence() / 8)
    feature.append(atom.IsInRing() * 1)
    feature.append(atom.GetIsAromatic() * 1)

    f = [0] * (len(Chiral) - 1)
    if Chiral.get(str(atom.GetChiralTag()), 0) != 0:
        f[Chiral.get(str(atom.GetChiralTag()), 0)] = 1
    feature.extend(f)

    f = [0] * (len(Hybridization) - 1)
    if Hybridization.get(str(atom.GetHybridization()), 0) != 0:
        f[Hybridization.get(str(atom.GetHybridization()), 0)] = 1
    feature.extend(f)

    return (feature)


def calc_structure_feature(c, flag, label):
    feature = [0] * structInfo

    if c == '(':
        feature[0] = 1
        flag = 0
    elif c == ')':
        feature[1] = 1
        flag = 0
    elif c == '[':
        feature[2] = 1
        flag = 0
    elif c == ']':
        feature[3] = 1
        flag = 0
    elif c == '.':
        feature[4] = 1
        flag = 0
    elif c == ':':
        feature[5] = 1
        flag = 0
    elif c == '=':
        feature[6] = 1
        flag = 0
    elif c == '#':
        feature[7] = 1
        flag = 0
    elif c == '\\':
        feature[8] = 1
        flag = 0
    elif c == '/':
        feature[9] = 1
        flag = 0
    elif c == '@':
        feature[10] = 1
        flag = 0
    elif c == '+':
        feature[11] = 1
        flag = 1
    elif c == '-':
        feature[12] = 1
        flag = 1
    elif c.isdigit() == True:
        if flag == 0:
            if c in label:
                feature[20] = 1
            else:
                label.append(c)
                feature[19] = 1
        else:
            feature[int(c) - 1 + 12] = 1
            flag = 0
    return (feature, flag, label)


def calc_featurevector(mol, smiles, atomsize):
    flag = 0
    label = []
    molfeature = []
    idx = 0
    j = 0

    for c in smiles:
        if islower(c) == True:
            continue
        elif isupper(c) == True:
            if c == 'H':
                molfeature.extend(H_Vector)
            else:
                molfeature.extend(calc_atom_feature(rdchem.Mol.GetAtomWithIdx(mol, idx)))
                idx = idx + 1
            molfeature.extend([0] * structInfo)
            j = j + 1

        else:
            molfeature.extend([0] * atomInfo)
            f, flag, label = calc_structure_feature(c, flag, label)
            molfeature.extend(f)
            j = j + 1

    # 0-Padding
    molfeature.extend([0] * (atomsize - j) * lensize)
    return (molfeature)


def mol_to_feature(mol, n, atomsize):
    try:
        defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True, rootedAtAtom=int(n))
    except:
        defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True)
    try:
        isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True, rootedAtAtom=int(n))
    except:
        isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True)
    return calc_featurevector(Chem.MolFromSmiles(defaultSMILES), isomerSMILES, atomsize)


def mol_to_allSMILESfeature(mol, atomsize):
    idx, features = 0, []
    while idx < mol.GetNumAtoms():
        try:
            defaultSMILES = Chem.MolToSmiles(mol, kekuleSmiles=False, isomericSmiles=True, rootedAtAtom=int(idx))
        except:
            break
        isomerSMILES = Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True, rootedAtAtom=int(idx))
        features.append(calc_featurevector(Chem.MolFromSmiles(defaultSMILES), isomerSMILES, atomsize))
        idx = idx + 1
    return (features)

# %% [markdown]
# ### Ensemble

# %%
import tensorflow as tf
import pickle
import numpy as np
import time
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"
print("current pid:", os.getpid())

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[3], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[3], True)
        print("should be ok...right?")
    except RuntimeError as e:
        print(e)
else:
    print("gpu unlimited?")

def getScore(proteinName):
    testlistX, testlistY = [], []
    testfile = "/content/drive/MyDrive/TOX21/" + proteinName + '_score.smiles'
    testf = open(testfile)
    lines = testf.readlines()
    for line in lines:
        splitted = line.split("\t")
        if len(splitted[0]) >= 200:
            continue
        testlistY.append(float(splitted[1]))
    testf.close()
    # print(len(testlistY))

    return testlistY

testRes12 = [[] for i in range(12)]

testRes12[0].extend(getScore("NR-AR-LBD"))
testRes12[1].extend(getScore("NR-AR"))
testRes12[2].extend(getScore("NR-AhR"))
testRes12[3].extend(getScore("NR-Aromatase"))
testRes12[4].extend(getScore("NR-ER-LBD"))
testRes12[5].extend(getScore("NR-ER"))
testRes12[6].extend(getScore("NR-PPAR-gamma"))
testRes12[7].extend(getScore("SR-ARE"))
testRes12[8].extend(getScore("SR-ATAD5"))
testRes12[9].extend(getScore("SR-HSE"))
testRes12[10].extend(getScore("SR-MMP"))
testRes12[11].extend(getScore("SR-p53"))


def loadPickle(givenNum, logitsWhole):
    curLogits = pickle.load(open("logit"+givenNum, "rb")) #tf.float32 dtype
    if logitsWhole is None:
        logitsWhole = curLogits
    else:
        for i in range(12):
            logitsWhole[i] = tf.math.add(curLogits[i], logitsWhole[i])
    return logitsWhole

def applysigmoid(alist):
    #tmpres = [[] for i in range(12)]
    for i in range(12):
        alist[i] = tf.math.sigmoid(alist[i])
    return alist


testLogits12 = None
testLogits12 = loadPickle("0", testLogits12)
print(testLogits12[0][0])
testLogits12 = loadPickle("0", testLogits12)
print(testLogits12[0][0])
testLogits12 = loadPickle("0", testLogits12)
#print(testLogits12[0][0])
testLogits12 = applysigmoid(testLogits12)
#tfRes12
AUCFunc = tf.keras.metrics.AUC()

start = time.time()
AUCFunc.reset_states()

for i in range(12):
    AUCFunc.update_state(y_true=testRes12[i], y_pred=testLogits12[i])
print('AUC {:.4f}'.format(AUCFunc.result()))
print("time taken:", time.time() - start)
# Out:
# current pid: 4472
# gpu unlimited?
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-a39bc943fc35> in <cell line: 69>()
#      67
#      68 testLogits12 = None
# ---> 69 testLogits12 = loadPickle("0", testLogits12)
#      70 print(testLogits12[0][0])
#      71 testLogits12 = loadPickle("0", testLogits12)
#
# <ipython-input-3-a39bc943fc35> in loadPickle(givenNum, logitsWhole)
#      51
#      52 def loadPickle(givenNum, logitsWhole):
# ---> 53     curLogits = pickle.load(open("logit"+givenNum, "rb")) #tf.float32 dtype
#      54     if logitsWhole is None:
#      55         logitsWhole = curLogits
#
# FileNotFoundError: [Errno 2] No such file or directory: 'logit0'

# %% [markdown]
# ## selfAttMulticlass

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import time
import numpy as np
import os
import argparse
from rdkit import Chem

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle
import itertools

# %%
log_path =  "./logs/"
try:
    os.rmdir(log_path)
except OSError as e:
    print("Error: %s : %s" % (log_path, e.strerror))
    TC = tf.keras.callbacks.TensorBoard("logs", 2, write_graph=True)

os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1, 2, 3"
print("current pid:", os.getpid())

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[3], 'GPU')
        tf.config.experimental.set_memory_growth(gpus[3], True)
        print("should be ok...right?")
    except RuntimeError as e:
        print(e)
else:
    print("gpu unlimited?")

parser = argparse.ArgumentParser(description='argparse')
parser.add_argument('--batchsize', '-b', type=int, default=128, help='Number of moleculars in each mini-batch')
parser.add_argument('--epochs', '-e', type=int, default=50, help='Number of sweeps over the dataset to train')
parser.add_argument('--input', '-i', default='/content/drive/MyDrive/TOX21', help='Input SDFs Dataset')
parser.add_argument('--num_layers', type=int, default=7, help='No. of hidden perceptron')
parser.add_argument('--d_model', type=int, default=128, help='No. of hidden perceptron')  # default 512
parser.add_argument('--dff', type=int, default=1024, help='No. of hidden perceptron')
parser.add_argument('--num_heads', type=int, default=1, help='No. of hidden perceptron')
parser.add_argument('--dropout_rate', '-d', type=float, default=0.1, help='No. of hidden perceptron')
parser.add_argument('--lr', '-l', type=float, default=0.00005, help='No. of hidden perceptron')
parser.add_argument('--max_vocab_size', type=int, default=1025, help='')
parser.add_argument('--atomsize', '-c', type=int, default=400, help='max length of smiles')
parser.add_argument('--seq_size', '-s', type=int, default=400, help='seq length of smiles fp2vec')
parser.add_argument('--pickle_load', type=bool, default=False, help='pickle embedding')
parser.add_argument('--weight_load', type=bool, default=False, help='pickle embedding')
parser.add_argument('--_test', type=bool, default=False, help='pickle embedding')#True
parser.add_argument('--current_num', default="for3", help='name says it')
parser.add_argument('--n_out', type=int, default=1, help='No. of output perceptron (class)')
parser.add_argument('--num_randoms', type=int, default=5, help='No. of output perceptron (class)')

args = parser.parse_args('')

def posNegNums(ydata):
    cntP = 0
    cntN = 0
    for ele in ydata:
        if ele == 1:
            cntP += 1
        else:
            cntN += 1
    return cntP, cntN
# Out:
# Error: ./logs/ : No such file or directory
# current pid: 9268
# gpu unlimited?

# %%
# detaset function definition
def random_list(x, seed=0):
    np.random.seed(seed)
    np.random.shuffle(x)

"""
def char2indices_no2(listStr, dicC2I):
    listIndices = [0] * args.seq_size
    charlist = listStr
    for i, c in enumerate(charlist):
        if c not in dicC2I:
            dicC2I[c] = len(dicC2I) + 1
            listIndices[i] = dicC2I[c]
        else:
            listIndices[i] = dicC2I[c]
    return listIndices
"""

def char2indices(listStr, dicC2I):
    listIndices = [0] * args.seq_size
    charlist = listStr
    size = len(listStr)
    twoChars = {"Al": 1, "Au": 1, "Ag": 1, "As": 1, "Ba": 1, "Be": 1, "Bi": 1, "Br": 1, "Ca": 1, "Cd": 1, "Cl": 1,
                "Co": 1, "Cr": 1, "Cu": 1, "Dy": 1, "Fe": 1, "Gd": 1, "Ge": 1, "In": 1, "Li": 1, "Mg": 1, "Mn": 1,
                "Mo": 1, "Na": 1, "Ni": 1, "Nd": 1, "Pb": 1, "Pt": 1, "Pd": 1, "Ru": 1, "Sb": 1, "Se": 1, "se": 1,
                "Si": 1, "Sn": 1, "Sr": 1, "Ti": 1, "Tl": 1, "Yb": 1, "Zn": 1, "Zr": 1}
    prevTwoCharsFlag = False
    indexForList = 0
    for i, c in enumerate(charlist):
        if prevTwoCharsFlag:
            prevTwoCharsFlag = False
            continue

        if i != size - 1 and "".join(charlist[i:i+2]) in twoChars:
            two = "".join(charlist[i:i+2])
            if two not in dicC2I:
                dicC2I[two] = len(dicC2I) + 1
                listIndices[indexForList] = dicC2I[two]
                indexForList += 1
            else:
                listIndices[indexForList] = dicC2I[two]
                indexForList += 1
            prevTwoCharsFlag = True
        else:
            if c not in dicC2I:
                dicC2I[c] = len(dicC2I) + 1
                listIndices[indexForList] = dicC2I[c]
                indexForList += 1
            else:
                listIndices[indexForList] = dicC2I[c]
                indexForList += 1
    return listIndices


def makeDataForSmilesOnly(proteinName, dicC2I):
    listX, listY = [], []
    proteinName = 'NR-AhR'
    afile = args.input + '/' + proteinName + '_wholetraining.smiles'
    f = open(afile, "r")
    lines = f.readlines()
    cntTooLong = 0
    weirdButUseful = 0
    for line in lines:
        splitted = line.split(" ")
        if len(splitted[0]) >= args.seq_size:
            cntTooLong += 1
            if splitted[1] == "1":
                weirdButUseful += 1
            continue
        listX.append(char2indices(splitted[0], dicC2I))  # length can vary
        listY.append(float(splitted[1]))
    f.close()

    # print("how many weird cases exist?", cntTooLong, weirdButUseful)
    train_x, test_x, train_y, test_y = train_test_split(listX, listY, test_size=0.1)
    train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.1)
    pos_num, neg_num = posNegNums(train_y)
    train_tf = tf.data.Dataset.from_tensor_slices((train_x, train_y)).batch(args.batchsize).shuffle(10000)
    valid_tf = tf.data.Dataset.from_tensor_slices((valid_x, valid_y)).batch(args.batchsize).shuffle(10000)
    test_tf = tf.data.Dataset.from_tensor_slices((test_x, test_y)).batch(args.batchsize)
    """
    train_x, valid_x, train_y, valid_y = train_test_split(listX, listY, test_size=0.1)
    train_tf = tf.data.Dataset.from_tensor_slices((train_x, train_y)).batch(args.batchsize).shuffle(10000)
    valid_tf = tf.data.Dataset.from_tensor_slices((valid_x, valid_y)).batch(args.batchsize).shuffle(10000)

    testlistX, testlistY = [], []
    testfile = args.input + "/" + proteinName + '_score.smiles'
    testf = open(testfile)
    lines = testf.readlines()
    for line in lines:
        splitted = line.split("\t")
        if len(splitted[0]) >= args.seq_size:
            continue
        testlistX.append(char2indices(splitted[0], dicC2I))  # length can vary
        testlistY.append(float(splitted[1]))
    testf.close()

    test_tf = tf.data.Dataset.from_tensor_slices((testlistX, testlistY)).batch(args.batchsize)
    """
    return train_tf, valid_tf, test_tf, pos_num, neg_num, train_x, valid_x, test_x#testlistX


if args.pickle_load:
    embeddings_, dicC2I = pickle.load(open(args.current_num+"saved_emb.pkl", "rb"))
else:
    dicC2I = {}
pos_num, neg_num = 0, 0


if not args._test:
    train_tf1, valid_tf1, test_tf1, pos1, neg1, _, _, _ = makeDataForSmilesOnly("NR-AR-LBD", dicC2I)
    train_tf2, valid_tf2, test_tf2, pos2, neg2, train2, valid2, test2 = makeDataForSmilesOnly("NR-AR", dicC2I)
    train_tf3, valid_tf3, test_tf3, pos3, neg3, _, _, _ = makeDataForSmilesOnly("NR-AhR", dicC2I)
    train_tf4, valid_tf4, test_tf4, pos4, neg4, _, _, _ = makeDataForSmilesOnly("NR-Aromatase", dicC2I)
    train_tf5, valid_tf5, test_tf5, pos5, neg5, _, _, _ = makeDataForSmilesOnly("NR-ER-LBD", dicC2I)
    train_tf6, valid_tf6, test_tf6, pos6, neg6, _, _, _ = makeDataForSmilesOnly("NR-ER", dicC2I)
    train_tf7, valid_tf7, test_tf7, pos7, neg7, _, _, _ = makeDataForSmilesOnly("NR-PPAR-gamma", dicC2I)
    train_tf8, valid_tf8, test_tf8, pos8, neg8, _, _, _ = makeDataForSmilesOnly("SR-ARE", dicC2I)
    train_tf9, valid_tf9, test_tf9, pos9, neg9, _, _, _ = makeDataForSmilesOnly("SR-ATAD5", dicC2I)
    train_tf10, valid_tf10, test_tf10, pos10, neg10, _, _, _ = makeDataForSmilesOnly("SR-HSE", dicC2I)
    train_tf11, valid_tf11, test_tf11, pos11, neg11, _, _, _ = makeDataForSmilesOnly("SR-MMP", dicC2I)
    train_tf12, valid_tf12, test_tf12, pos12, neg12, _, _, _ = makeDataForSmilesOnly("SR-p53", dicC2I)
    pos_num = pos1 + pos2 + pos3 + pos4 + pos5 + pos6 + pos7 + pos8 + pos9 + pos10 + pos11 + pos12
    neg_num = neg1 + neg2 + neg3 + neg4 + neg5 + neg6 + neg7 + neg8 + neg9 + neg10 + neg11 + neg12

print("pos/neg:", pos_num, neg_num)


def scaled_dot_product_attention(q, k, v, mask):
    """Calculate the attention weights.
    q, k, v must have matching leading dimensions.
    k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
    The mask has different shapes depending on its type(padding or look ahead) but it must be broadcastable for addition.
    Args:
      q: query shape == (..., seq_len_q, depth)
      k: key shape == (..., seq_len_k, depth)
      v: value shape == (..., seq_len_v, depth_v)
      mask: Float tensor with shape broadcastable to (..., seq_len_q, seq_len_k). Defaults to None.
    Returns:
      output, attention_weights
    """
    matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
    # scale matmul_qk
    dk = tf.cast(tf.shape(k)[-1], tf.float32)
    scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)
    # add the mask to the scaled tensor.
    if mask is not None:
        scaled_attention_logits += (mask * -1e9)
        # softmax is normalized on the last axis (seq_len_k) so that the scores
    # add up to 1.
    attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)
    output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)
    return output, attention_weights
# Out:
# pos/neg: 7501 59927

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model_, num_heads_):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads_
        self.d_model = d_model_
        assert d_model_ % self.num_heads == 0
        self.depth = d_model_ // self.num_heads
        self.wq = tf.keras.layers.Dense(d_model_)
        self.wk = tf.keras.layers.Dense(d_model_)
        self.wv = tf.keras.layers.Dense(d_model_)
        self.dense = tf.keras.layers.Dense(d_model_)

    def split_heads(self, x_, batch_size):
        """Split the last dimension into (num_heads, depth).
        Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
        """
        x_ = tf.reshape(x_, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x_, perm=[0, 2, 1, 3])

    def call(self, v, k, q, mask):
        batch_size = tf.shape(q)[0]
        q = self.wq(q)  # (batch_size, seq_len, d_model)
        k = self.wk(k)  # (batch_size, seq_len, d_model)
        v = self.wv(v)  # (batch_size, seq_len, d_model)
        q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
        k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
        v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
        # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
        # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
        scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
        scaled_attention = tf.transpose(scaled_attention,
                                        perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)
        concat_attention = tf.reshape(scaled_attention,
                                      (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)
        output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        return output, attention_weights


def point_wise_feed_forward_network(d_model_, dff_):
    return tf.keras.Sequential([
        tf.keras.layers.Dense(dff_, activation="relu", bias_initializer='glorot_uniform', use_bias=True),  # (batch_size, seq_len, dff)
        tf.keras.layers.Dense(d_model_, bias_initializer='glorot_uniform', use_bias=True) # (batch_size, seq_len, d_model)
    ])


class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model_, num_heads_, dff_, rate=0.1):
        super(EncoderLayer, self).__init__()
        self.mha = MultiHeadAttention(d_model_, num_heads_)
        self.ffn = point_wise_feed_forward_network(d_model_, dff_)
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, x, training, mask):
        attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
        ffn_output = self.dropout2(ffn_output, training=training)
        out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
        return out2

"""
def get_angles(pos, i, d_model_):
    angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(d_model_))
    return pos * angle_rates


def positional_encoding(position, d_model_):
    angle_rads = get_angles(np.arange(position)[:, np.newaxis], np.arange(d_model_)[np.newaxis, :], d_model_)
    # apply sin to even indices in the array; 2i
    angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
    # apply cos to odd indices in the array; 2i+1
    angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    pos_encoding = angle_rads[np.newaxis, ...]
    return tf.cast(pos_encoding, dtype=tf.float32)
"""

class CustomFC(tf.keras.layers.Layer):
    def __init__(self, output_bias, d_model_):
        super(CustomFC, self).__init__()
        self.d_model = d_model_
        self.finalFC1 = tf.keras.layers.Dense(args.n_out, bias_initializer=output_bias)
        self.finalFC2 = tf.keras.layers.Dense(args.n_out, bias_initializer=output_bias)

    def call(self, inputs, seq_len):
        out = self.finalFC1(inputs)
        ##out = tf.keras.layers.Reshape([self.d_model])(out)#seq_len])(out)
        out = tf.keras.layers.Reshape([seq_len])(out)
        out = self.finalFC2(out)
        return out


class CustomHot(tf.keras.layers.Layer):
    def __init__(self):
        super(CustomHot, self).__init__()

    def call(self, inputs):
        return tf.one_hot(inputs, 12)

class CustomRSum(tf.keras.layers.Layer):
    def __init__(self):
        super(CustomRSum, self).__init__()
    def call(self, inputs, dWhich):
        return tf.math.reduce_sum(inputs * dWhich, axis=1)  # only the 1 instnce survives

# %%
class Encoder(tf.keras.Model):
    def __init__(self, num_layers_, d_model_, num_heads_, dff_, output_bias, rate=0.1, seq_size=None):  # input_vocab and max_vocab are the same
        super(Encoder, self).__init__()
        if output_bias is not None:
            output_bias = tf.keras.initializers.Constant(output_bias)
        self.seq_size = seq_size
        self.d_model = d_model_
        self.num_layers = num_layers_
        self.enc_layers = [EncoderLayer(d_model_, num_heads_, dff_, rate) for _ in range(num_layers_)]
        self.dropout = tf.keras.layers.Dropout(rate)
        self.pads1 = tf.constant([[0, 0], [0, 7 - 1], [0, 0]])
        self.conv1 = tf.keras.layers.Conv2D(d_model_, [7, d_model_], strides=1)
        #self.pos_encoding = positional_encoding(seq_size, self.d_model)

        self.FC1 = CustomFC(output_bias, self.d_model)
        self.FC2 = CustomFC(output_bias, self.d_model)
        self.FC3 = CustomFC(output_bias, self.d_model)
        self.FC4 = CustomFC(output_bias, self.d_model)
        self.FC5 = CustomFC(output_bias, self.d_model)
        self.FC6 = CustomFC(output_bias, self.d_model)
        self.FC7 = CustomFC(output_bias, self.d_model)
        self.FC8 = CustomFC(output_bias, self.d_model)
        self.FC9 = CustomFC(output_bias, self.d_model)
        self.FC10 = CustomFC(output_bias, self.d_model)
        self.FC11 = CustomFC(output_bias, self.d_model)
        self.FC12 = CustomFC(output_bias, self.d_model)

    def call(self, x_, whichClass, training, mask_att, justmask):
        # x_.set_shape([None, self.seq_size])
        # adding embedding and position encoding.
        #x_ += self.pos_encoding[:, :self.seq_size, :]
        x_ = tf.keras.layers.Reshape([self.seq_size, self.d_model, 1])(x_)
        x_ = self.conv1(x_)
        x_ = tf.keras.layers.Reshape([self.seq_size - 7 + 1, self.d_model])(x_)
        x_ = tf.pad(x_, self.pads1)#shape (batch, 200, d_model)
        for i in range(self.num_layers):
            x_ = self.enc_layers[i](x_, training, mask_att)
        out = self.dropout(x_, training=training)
        cl1 = self.FC1(out, self.seq_size)
        cl2 = self.FC2(out, self.seq_size)
        cl3 = self.FC3(out, self.seq_size)
        cl4 = self.FC4(out, self.seq_size)
        cl5 = self.FC5(out, self.seq_size)
        cl6 = self.FC6(out, self.seq_size)
        cl7 = self.FC7(out, self.seq_size)
        cl8 = self.FC8(out, self.seq_size)
        cl9 = self.FC9(out, self.seq_size)
        cl10 = self.FC10(out, self.seq_size)
        cl11 = self.FC11(out, self.seq_size)
        cl12 = self.FC12(out, self.seq_size)
        x_out = tf.keras.layers.concatenate([cl1, cl2, cl3, cl4, cl5, cl6, cl7, cl8, cl9, cl10, cl11, cl12])#default axis -1 ==> batch, 12
        decideWhich = CustomHot()(whichClass)
        pred_logit = CustomRSum()(x_out, decideWhich)
        return pred_logit, tf.math.sigmoid(pred_logit)


class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model_, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        self.d_model = d_model_
        self.d_model = tf.cast(self.d_model, tf.float32)
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps ** -1.5)
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)


def loss_function(real, pred_logit, sampleW=None):
    cross_ent = tf.nn.weighted_cross_entropy_with_logits(logits=pred_logit, labels=real, pos_weight=sampleW)
    return tf.reduce_sum(cross_ent)#reduce_mean


def create_padding_mask_fp2vec(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    # add extra dimensions to add the padding
    # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :], seq  # (batch_size, 1, 1, seq_len)


def create_padding_mask_scfp(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    seq = tf.cast(tf.math.argmin(seq, axis=-1), tf.float32)
    # add extra dimensions to add the padding
    # to the attention logits.
    return seq[:, tf.newaxis, tf.newaxis, :], seq  # (batch_size, 1, 1, atom_size)


learning_rate = args.lr  # 0.0001#CustomSchedule(args.d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate)  # , beta_1=0.9, beta_2=0.98, epsilon=1e-9)

train_loss = tf.keras.metrics.Mean(name='train_loss')
AUCFunc = tf.keras.metrics.AUC()
accFunc = tf.keras.metrics.BinaryAccuracy()
precFunc = tf.keras.metrics.Precision(name='precFunc')
recallFunc = tf.keras.metrics.Recall(name='recallFunc')
initial_bias = np.log([pos_num / neg_num])
#weight_for_0 = tf.convert_to_tensor((1 / neg_num)*(pos_num + neg_num)/2.0, dtype=tf.float32)#not used
weight_for_1 = tf.convert_to_tensor((1 / pos_num)*(pos_num + neg_num)/2.0, dtype=tf.float32)

encoder = Encoder(args.num_layers, args.d_model, args.num_heads, args.dff, output_bias=initial_bias, rate=args.dropout_rate, seq_size=args.seq_size)
TC.set_model(encoder)
checkpoint_dir = "trS"+args.current_num+"/cp.ckpt"
if args.pickle_load == False:
    bit_size = len(dicC2I) #1024
    emb = tf.Variable(tf.random.uniform([bit_size, args.d_model], -1, 1), dtype=tf.float32)
    pads = tf.constant([[1,0], [0,0]])
    embeddings_ = tf.pad(emb, pads)#1025, 200
    encoder.save_weights(checkpoint_dir)
else:
    print("embedding loaded already")
    if args.weight_load == True:
        encoder.load_weights(checkpoint_dir)

# %%
def train_step(inp_, real, whichClass):  # shape is [batch, seq_len]
    inp_padding_mask, justmask = create_padding_mask_fp2vec(inp_)
    with tf.GradientTape() as tape:
        pred_logit, pred = encoder(tf.nn.embedding_lookup(embeddings_, inp_), whichClass, True, inp_padding_mask, justmask)
        loss = loss_function(real, pred_logit, sampleW=weight_for_1)
    gradients = tape.gradient(loss, encoder.trainable_variables)
    optimizer.apply_gradients(zip(gradients, encoder.trainable_variables))
    train_loss(loss)
    print(loss)


def eval_step(inp_, real, whichClass):
    inp_padding_mask, justmask = create_padding_mask_fp2vec(inp_)
    _, pred = encoder(tf.nn.embedding_lookup(embeddings_, inp_), whichClass, False, inp_padding_mask, justmask)

    precFunc.update_state(y_true=real, y_pred=pred)
    recallFunc.update_state(y_true=real, y_pred=pred)
    AUCFunc.update_state(y_true=real, y_pred=pred)
    accFunc.update_state(y_true=real, y_pred=pred)


def test_step(inp_, real, whichClass):
    inp_padding_mask, justmask = create_padding_mask_fp2vec(inp_)
    logit, pred = encoder(tf.nn.embedding_lookup(embeddings_, inp_), whichClass, False, inp_padding_mask, justmask)
    precFunc.update_state(y_true=real, y_pred=pred)
    recallFunc.update_state(y_true=real, y_pred=pred)
    AUCFunc.update_state(y_true=real, y_pred=pred)
    accFunc.update_state(y_true=real, y_pred=pred)
    #print(len(logit), len(real))


def indices2chars(listx, dicC2I):#listx shape = whole_size, 200
    dicI2C = {}
    for key in dicC2I:
        dicI2C[dicC2I[key]] = key

    retList = []
    for instance in listx:
        tmplist = []
        for index in instance:
            if index == 0:#didn't use the 0 as index
                break
            tmplist.append(dicI2C[index])
        retList.append(tmplist)
    return retList


f2w = open("performanceS", "w")
bestEpoch = 0
bestAUC = 0
for epoch in range(args.epochs):
    start = time.time()
    train_loss.reset_states()
    precFunc.reset_states()
    recallFunc.reset_states()
    AUCFunc.reset_states()
    accFunc.reset_states()
    for tf1, tf2, tf3, tf4, tf5, tf6, tf7, tf8, tf9, tf10, tf11, tf12 in itertools.zip_longest(train_tf1, train_tf2, train_tf3, train_tf4, train_tf5, train_tf6, train_tf7,
                                                     train_tf8, train_tf9, train_tf10, train_tf11, train_tf12):
        if tf1:
            train_step(tf1[0], tf1[1], 0)
        if tf2:
            train_step(tf2[0], tf2[1], 1)
        if tf3:
            train_step(tf3[0], tf3[1], 2)
        if tf4:
            train_step(tf4[0], tf4[1], 3)
        if tf5:
            train_step(tf5[0], tf5[1], 4)
        if tf6:
            train_step(tf6[0], tf6[1], 5)
        if tf7:
            train_step(tf7[0], tf7[1], 6)
        if tf8:
            train_step(tf8[0], tf8[1], 7)
        if tf9:
            train_step(tf9[0], tf9[1], 8)
        if tf10:
            train_step(tf10[0], tf10[1], 9)
        if tf11:
            train_step(tf11[0], tf11[1], 10)
        if tf12:
            train_step(tf12[0], tf12[1], 11)


    print('Train Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))
    f2w.write('Train Epoch {} Loss {:.4f}'.format(epoch + 1, train_loss.result()))
    f2w.write("\n")
    if epoch % 1 == 0:
        for tf1, tf2, tf3, tf4, tf5, tf6, tf7, tf8, tf9, tf10, tf11, tf12 in itertools.zip_longest(valid_tf1, valid_tf2, valid_tf3, valid_tf4, valid_tf5, valid_tf6,
                                             valid_tf7, valid_tf8, valid_tf9, valid_tf10, valid_tf11, valid_tf12):
            if tf1:
                eval_step(tf1[0], tf1[1], 0)
            if tf2:
                eval_step(tf2[0], tf2[1], 1)
            if tf3:
                eval_step(tf3[0], tf3[1], 2)
            if tf4:
                eval_step(tf4[0], tf4[1], 3)
            if tf5:
                eval_step(tf5[0], tf5[1], 4)
            if tf6:
                eval_step(tf6[0], tf6[1], 5)
            if tf7:
                eval_step(tf7[0], tf7[1], 6)
            if tf8:
                eval_step(tf8[0], tf8[1], 7)
            if tf9:
                eval_step(tf9[0], tf9[1], 8)
            if tf10:
                eval_step(tf10[0], tf10[1], 9)
            if tf11:
                eval_step(tf11[0], tf11[1], 10)
            if tf12:
                eval_step(tf12[0], tf12[1], 11)


        if bestAUC < AUCFunc.result():
            bestEpoch = epoch + 1
            bestAUC = AUCFunc.result()
            encoder.save_weights(checkpoint_dir)
            print('Saving checkpoint for epoch {} at {}'.format(epoch + 1, checkpoint_dir))
        print('Valid prec {:.4f} recall {:.4f} AUC {:.4f}, acc {:.4f}'.format(precFunc.result(), recallFunc.result(),
                                                                              AUCFunc.result(), accFunc.result()))
        logs = {'auc': AUCFunc.result(), 'loss': train_loss.result()}
        TC.on_epoch_end(epoch, logs)

        f2w.write('Valid prec {:.4f} recall {:.4f} AUC {:.4f}, acc {:.4f}'.format(precFunc.result(), recallFunc.result(),
                                                                                  AUCFunc.result(), accFunc.result()))
        f2w.write("\n")
        f2w.flush()
    print('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
f2w.close()
# Out:
# tf.Tensor(300.279, shape=(), dtype=float32)
# tf.Tensor(741.957, shape=(), dtype=float32)
# tf.Tensor(135.27246, shape=(), dtype=float32)
# tf.Tensor(106.79764, shape=(), dtype=float32)
# tf.Tensor(112.41835, shape=(), dtype=float32)
# tf.Tensor(192.83154, shape=(), dtype=float32)
# tf.Tensor(150.48494, shape=(), dtype=float32)
# tf.Tensor(139.19562, shape=(), dtype=float32)
# tf.Tensor(350.86877, shape=(), dtype=float32)
# tf.Tensor(163.20071, shape=(), dtype=float32)
# tf.Tensor(394.92896, shape=(), dtype=float32)
# tf.Tensor(289.56152, shape=(), dtype=float32)
# tf.Tensor(96.12006, shape=(), dtype=float32)
# tf.Tensor(418.4015, shape=(), dtype=float32)
# tf.Tensor(124.847015, shape=(), dtype=float32)
# tf.Tensor(144.93187, shape=(), dtype=float32)
# tf.Tensor(235.04886, shape=(), dtype=float32)
# tf.Tensor(119.37553, shape=(), dtype=float32)
# tf.Tensor(145.44878, shape=(), dtype=float32)
# tf.Tensor(142.76617, shape=(), dtype=float32)
# tf.Tensor(133.04637, shape=(), dtype=float32)
# tf.Tensor(132.9715, shape=(), dtype=float32)
# tf.Tensor(381.77362, shape=(), dtype=float32)
# tf.Tensor(172.80644, shape=(), dtype=float32)
# tf.Tensor(124.257965, shape=(), dtype=float32)
# tf.Tensor(109.24011, shape=(), dtype=float32)
# tf.Tensor(114.57463, shape=(), dtype=float32)
# tf.Tensor(106.955574, shape=(), dtype=float32)
# tf.Tensor(133.33458, shape=(), dtype=float32)
# tf.Tensor(139.61313, shape=(), dtype=float32)
# tf.Tensor(152.39722, shape=(), dtype=float32)
# tf.Tensor(136.71127, shape=(), dtype=float32)
# tf.Tensor(166.73334, shape=(), dtype=float32)
# tf.Tensor(117.84065, shape=(), dtype=float32)
# tf.Tensor(130.83841, shape=(), dtype=float32)
# tf.Tensor(160.07559, shape=(), dtype=float32)
# tf.Tensor(110.611496, shape=(), dtype=float32)
# tf.Tensor(94.43465, shape=(), dtype=float32)
# tf.Tensor(129.63623, shape=(), dtype=float32)
# tf.Tensor(110.23735, shape=(), dtype=float32)
# tf.Tensor(126.72168, shape=(), dtype=float32)
# tf.Tensor(154.52322, shape=(), dtype=float32)
# tf.Tensor(92.78584, shape=(), dtype=float32)
# tf.Tensor(123.193634, shape=(), dtype=float32)
# tf.Tensor(108.11494, shape=(), dtype=float32)
# tf.Tensor(102.346664, shape=(), dtype=float32)
# tf.Tensor(90.79572, shape=(), dtype=float32)
# tf.Tensor(146.60869, shape=(), dtype=float32)
# tf.Tensor(93.18979, shape=(), dtype=float32)
# tf.Tensor(120.57555, shape=(), dtype=float32)
# tf.Tensor(97.080444, shape=(), dtype=float32)
# tf.Tensor(132.95975, shape=(), dtype=float32)
# tf.Tensor(113.17702, shape=(), dtype=float32)
# tf.Tensor(127.76685, shape=(), dtype=float32)
# tf.Tensor(153.7366, shape=(), dtype=float32)
# tf.Tensor(108.216, shape=(), dtype=float32)
# tf.Tensor(118.8191, shape=(), dtype=float32)
# tf.Tensor(106.38976, shape=(), dtype=float32)
# tf.Tensor(83.60288, shape=(), dtype=float32)
# tf.Tensor(88.45255, shape=(), dtype=float32)
# tf.Tensor(85.24098, shape=(), dtype=float32)
# tf.Tensor(83.60398, shape=(), dtype=float32)
# tf.Tensor(74.96364, shape=(), dtype=float32)
# tf.Tensor(122.73076, shape=(), dtype=float32)
# tf.Tensor(167.39803, shape=(), dtype=float32)
# tf.Tensor(162.39159, shape=(), dtype=float32)
# tf.Tensor(121.60085, shape=(), dtype=float32)
# tf.Tensor(77.73634, shape=(), dtype=float32)
# tf.Tensor(131.88196, shape=(), dtype=float32)
# tf.Tensor(130.98303, shape=(), dtype=float32)
# tf.Tensor(105.72899, shape=(), dtype=float32)
# tf.Tensor(108.65845, shape=(), dtype=float32)
# tf.Tensor(100.44524, shape=(), dtype=float32)
# tf.Tensor(122.05336, shape=(), dtype=float32)
# tf.Tensor(130.59615, shape=(), dtype=float32)
# tf.Tensor(107.848335, shape=(), dtype=float32)
# tf.Tensor(113.01202, shape=(), dtype=float32)
# tf.Tensor(182.36884, shape=(), dtype=float32)
# tf.Tensor(134.52747, shape=(), dtype=float32)
# tf.Tensor(90.899796, shape=(), dtype=float32)
# tf.Tensor(106.255295, shape=(), dtype=float32)
# tf.Tensor(110.747765, shape=(), dtype=float32)
# tf.Tensor(82.55765, shape=(), dtype=float32)
# tf.Tensor(88.04868, shape=(), dtype=float32)
# tf.Tensor(116.07623, shape=(), dtype=float32)
# tf.Tensor(113.213066, shape=(), dtype=float32)
# tf.Tensor(116.29494, shape=(), dtype=float32)
# tf.Tensor(109.22522, shape=(), dtype=float32)
# tf.Tensor(202.98663, shape=(), dtype=float32)
# tf.Tensor(136.52911, shape=(), dtype=float32)
# tf.Tensor(109.868225, shape=(), dtype=float32)
# tf.Tensor(137.1843, shape=(), dtype=float32)
# tf.Tensor(77.428345, shape=(), dtype=float32)
# tf.Tensor(112.12809, shape=(), dtype=float32)
# tf.Tensor(126.36917, shape=(), dtype=float32)
# tf.Tensor(98.25574, shape=(), dtype=float32)
# tf.Tensor(90.66466, shape=(), dtype=float32)
# tf.Tensor(79.343506, shape=(), dtype=float32)
# tf.Tensor(112.33117, shape=(), dtype=float32)
# tf.Tensor(101.696266, shape=(), dtype=float32)
# tf.Tensor(175.46945, shape=(), dtype=float32)
# tf.Tensor(111.459915, shape=(), dtype=float32)
# tf.Tensor(114.60909, shape=(), dtype=float32)
# tf.Tensor(78.47624, shape=(), dtype=float32)
# tf.Tensor(166.44798, shape=(), dtype=float32)
# tf.Tensor(98.25701, shape=(), dtype=float32)
# tf.Tensor(161.62057, shape=(), dtype=float32)
# tf.Tensor(105.058754, shape=(), dtype=float32)
# tf.Tensor(94.575584, shape=(), dtype=float32)
# tf.Tensor(129.36868, shape=(), dtype=float32)
# tf.Tensor(98.101875, shape=(), dtype=float32)
# tf.Tensor(137.84256, shape=(), dtype=float32)
# tf.Tensor(144.09387, shape=(), dtype=float32)
# tf.Tensor(147.23947, shape=(), dtype=float32)
# tf.Tensor(85.97455, shape=(), dtype=float32)
# tf.Tensor(111.54998, shape=(), dtype=float32)
# tf.Tensor(127.96603, shape=(), dtype=float32)
# tf.Tensor(99.0631, shape=(), dtype=float32)
# tf.Tensor(120.91606, shape=(), dtype=float32)
# tf.Tensor(119.75278, shape=(), dtype=float32)
# tf.Tensor(107.67116, shape=(), dtype=float32)
# tf.Tensor(131.78204, shape=(), dtype=float32)
# tf.Tensor(119.06141, shape=(), dtype=float32)
# tf.Tensor(81.014755, shape=(), dtype=float32)
# tf.Tensor(131.55373, shape=(), dtype=float32)
# tf.Tensor(185.2505, shape=(), dtype=float32)
# tf.Tensor(106.561195, shape=(), dtype=float32)
# tf.Tensor(118.04548, shape=(), dtype=float32)
# tf.Tensor(118.25485, shape=(), dtype=float32)
# tf.Tensor(85.30524, shape=(), dtype=float32)
# tf.Tensor(124.605995, shape=(), dtype=float32)
# tf.Tensor(95.506226, shape=(), dtype=float32)
# tf.Tensor(113.013756, shape=(), dtype=float32)
# tf.Tensor(79.34264, shape=(), dtype=float32)
# tf.Tensor(132.9855, shape=(), dtype=float32)
# tf.Tensor(141.60635, shape=(), dtype=float32)
# tf.Tensor(118.75273, shape=(), dtype=float32)
# tf.Tensor(110.481064, shape=(), dtype=float32)
# tf.Tensor(120.60213, shape=(), dtype=float32)
# tf.Tensor(106.31212, shape=(), dtype=float32)
# tf.Tensor(109.1229, shape=(), dtype=float32)
# tf.Tensor(103.92157, shape=(), dtype=float32)
# tf.Tensor(130.94756, shape=(), dtype=float32)
# tf.Tensor(100.40848, shape=(), dtype=float32)
# tf.Tensor(142.2859, shape=(), dtype=float32)
# tf.Tensor(76.1861, shape=(), dtype=float32)
# tf.Tensor(85.33157, shape=(), dtype=float32)
# tf.Tensor(83.64513, shape=(), dtype=float32)
# tf.Tensor(127.2003, shape=(), dtype=float32)
# tf.Tensor(136.00143, shape=(), dtype=float32)
# tf.Tensor(108.53792, shape=(), dtype=float32)
# tf.Tensor(92.70244, shape=(), dtype=float32)
# tf.Tensor(85.92096, shape=(), dtype=float32)
# tf.Tensor(166.54274, shape=(), dtype=float32)
# tf.Tensor(105.95617, shape=(), dtype=float32)
# tf.Tensor(138.51683, shape=(), dtype=float32)
# tf.Tensor(81.63258, shape=(), dtype=float32)
# tf.Tensor(65.71398, shape=(), dtype=float32)
# tf.Tensor(84.09605, shape=(), dtype=float32)
# tf.Tensor(92.53287, shape=(), dtype=float32)
# tf.Tensor(162.635, shape=(), dtype=float32)
# tf.Tensor(137.51082, shape=(), dtype=float32)
# tf.Tensor(101.413864, shape=(), dtype=float32)
# tf.Tensor(111.89862, shape=(), dtype=float32)
# tf.Tensor(97.69995, shape=(), dtype=float32)
# tf.Tensor(81.084854, shape=(), dtype=float32)
# tf.Tensor(89.228676, shape=(), dtype=float32)
# tf.Tensor(109.21449, shape=(), dtype=float32)
# tf.Tensor(125.50017, shape=(), dtype=float32)
# tf.Tensor(83.75513, shape=(), dtype=float32)
# tf.Tensor(74.28711, shape=(), dtype=float32)
# tf.Tensor(95.84468, shape=(), dtype=float32)
# tf.Tensor(115.371506, shape=(), dtype=float32)
# tf.Tensor(159.24252, shape=(), dtype=float32)
# tf.Tensor(76.73024, shape=(), dtype=float32)
# tf.Tensor(88.976494, shape=(), dtype=float32)
# tf.Tensor(109.40738, shape=(), dtype=float32)
# tf.Tensor(118.8891, shape=(), dtype=float32)
# tf.Tensor(152.197, shape=(), dtype=float32)
# tf.Tensor(96.934166, shape=(), dtype=float32)
# tf.Tensor(76.57236, shape=(), dtype=float32)
# tf.Tensor(101.90841, shape=(), dtype=float32)
# tf.Tensor(95.87514, shape=(), dtype=float32)
# tf.Tensor(89.34593, shape=(), dtype=float32)
# tf.Tensor(112.98555, shape=(), dtype=float32)
# tf.Tensor(114.76931, shape=(), dtype=float32)
# tf.Tensor(93.89353, shape=(), dtype=float32)
# tf.Tensor(113.09379, shape=(), dtype=float32)
# tf.Tensor(78.31189, shape=(), dtype=float32)
# tf.Tensor(96.3877, shape=(), dtype=float32)
# tf.Tensor(110.52005, shape=(), dtype=float32)
# tf.Tensor(95.85785, shape=(), dtype=float32)
# tf.Tensor(64.25166, shape=(), dtype=float32)
# tf.Tensor(109.48113, shape=(), dtype=float32)
# tf.Tensor(139.23457, shape=(), dtype=float32)
# tf.Tensor(109.225204, shape=(), dtype=float32)
# tf.Tensor(130.36014, shape=(), dtype=float32)
# tf.Tensor(104.31051, shape=(), dtype=float32)
# tf.Tensor(137.43863, shape=(), dtype=float32)
# tf.Tensor(97.915726, shape=(), dtype=float32)
# tf.Tensor(121.968185, shape=(), dtype=float32)
# tf.Tensor(107.54264, shape=(), dtype=float32)
# tf.Tensor(83.95366, shape=(), dtype=float32)
# tf.Tensor(102.51178, shape=(), dtype=float32)
# tf.Tensor(88.96934, shape=(), dtype=float32)
# tf.Tensor(107.64594, shape=(), dtype=float32)
# tf.Tensor(131.82364, shape=(), dtype=float32)
# tf.Tensor(95.80192, shape=(), dtype=float32)
# tf.Tensor(93.47441, shape=(), dtype=float32)
# tf.Tensor(103.11889, shape=(), dtype=float32)
# tf.Tensor(89.98251, shape=(), dtype=float32)
# tf.Tensor(68.82488, shape=(), dtype=float32)
# tf.Tensor(94.583954, shape=(), dtype=float32)
# tf.Tensor(107.91792, shape=(), dtype=float32)
# tf.Tensor(97.58902, shape=(), dtype=float32)
# tf.Tensor(112.3305, shape=(), dtype=float32)
# tf.Tensor(123.73867, shape=(), dtype=float32)
# tf.Tensor(156.05582, shape=(), dtype=float32)
# tf.Tensor(117.90652, shape=(), dtype=float32)
# tf.Tensor(72.09241, shape=(), dtype=float32)
# tf.Tensor(134.8565, shape=(), dtype=float32)
# tf.Tensor(89.73743, shape=(), dtype=float32)
# tf.Tensor(115.62411, shape=(), dtype=float32)
# tf.Tensor(88.965515, shape=(), dtype=float32)
# tf.Tensor(113.02787, shape=(), dtype=float32)
# tf.Tensor(94.02977, shape=(), dtype=float32)
# tf.Tensor(108.2543, shape=(), dtype=float32)
# tf.Tensor(105.24127, shape=(), dtype=float32)
# tf.Tensor(94.56081, shape=(), dtype=float32)
# tf.Tensor(149.80719, shape=(), dtype=float32)
# tf.Tensor(106.12463, shape=(), dtype=float32)
# tf.Tensor(93.919624, shape=(), dtype=float32)
# tf.Tensor(100.24118, shape=(), dtype=float32)
# tf.Tensor(103.9221, shape=(), dtype=float32)
# tf.Tensor(101.981094, shape=(), dtype=float32)
# tf.Tensor(93.91148, shape=(), dtype=float32)
# tf.Tensor(92.12865, shape=(), dtype=float32)
# tf.Tensor(79.278244, shape=(), dtype=float32)
# tf.Tensor(102.70834, shape=(), dtype=float32)
# tf.Tensor(66.928856, shape=(), dtype=float32)
# tf.Tensor(113.76913, shape=(), dtype=float32)
# tf.Tensor(100.227875, shape=(), dtype=float32)
# tf.Tensor(99.517166, shape=(), dtype=float32)
# tf.Tensor(103.370865, shape=(), dtype=float32)
# tf.Tensor(89.044624, shape=(), dtype=float32)
# tf.Tensor(148.23978, shape=(), dtype=float32)
# tf.Tensor(131.74567, shape=(), dtype=float32)
# tf.Tensor(116.13669, shape=(), dtype=float32)
# tf.Tensor(114.51226, shape=(), dtype=float32)
# tf.Tensor(75.633606, shape=(), dtype=float32)
# tf.Tensor(76.690155, shape=(), dtype=float32)
# tf.Tensor(119.958046, shape=(), dtype=float32)
# tf.Tensor(102.4332, shape=(), dtype=float32)
# tf.Tensor(85.257225, shape=(), dtype=float32)
# tf.Tensor(103.82744, shape=(), dtype=float32)
# tf.Tensor(108.42746, shape=(), dtype=float32)
# tf.Tensor(99.73772, shape=(), dtype=float32)
# tf.Tensor(139.65701, shape=(), dtype=float32)
# tf.Tensor(97.114716, shape=(), dtype=float32)
# tf.Tensor(100.0428, shape=(), dtype=float32)
# tf.Tensor(80.54775, shape=(), dtype=float32)
# tf.Tensor(100.70897, shape=(), dtype=float32)
# tf.Tensor(82.53906, shape=(), dtype=float32)
# tf.Tensor(116.17758, shape=(), dtype=float32)
# tf.Tensor(100.2705, shape=(), dtype=float32)
# tf.Tensor(107.972336, shape=(), dtype=float32)
# tf.Tensor(97.535385, shape=(), dtype=float32)
# tf.Tensor(119.49922, shape=(), dtype=float32)
# tf.Tensor(110.59161, shape=(), dtype=float32)
# tf.Tensor(151.79117, shape=(), dtype=float32)
# tf.Tensor(62.942783, shape=(), dtype=float32)
# tf.Tensor(141.6304, shape=(), dtype=float32)
# tf.Tensor(96.74307, shape=(), dtype=float32)
# tf.Tensor(95.6478, shape=(), dtype=float32)
# tf.Tensor(75.888626, shape=(), dtype=float32)
# tf.Tensor(86.455826, shape=(), dtype=float32)
# tf.Tensor(84.663284, shape=(), dtype=float32)
# tf.Tensor(98.85665, shape=(), dtype=float32)
# tf.Tensor(101.29959, shape=(), dtype=float32)
# tf.Tensor(96.58441, shape=(), dtype=float32)
# tf.Tensor(64.65784, shape=(), dtype=float32)
# tf.Tensor(108.19255, shape=(), dtype=float32)
# tf.Tensor(129.71584, shape=(), dtype=float32)
# tf.Tensor(123.383484, shape=(), dtype=float32)
# tf.Tensor(83.88765, shape=(), dtype=float32)
# tf.Tensor(93.465225, shape=(), dtype=float32)
# tf.Tensor(110.15904, shape=(), dtype=float32)
# tf.Tensor(96.3779, shape=(), dtype=float32)
# tf.Tensor(65.55386, shape=(), dtype=float32)
# tf.Tensor(131.9725, shape=(), dtype=float32)
# tf.Tensor(105.59372, shape=(), dtype=float32)
# tf.Tensor(78.473434, shape=(), dtype=float32)
# tf.Tensor(99.62637, shape=(), dtype=float32)
# tf.Tensor(102.0299, shape=(), dtype=float32)
# tf.Tensor(90.74954, shape=(), dtype=float32)
# tf.Tensor(109.75354, shape=(), dtype=float32)
# tf.Tensor(78.73967, shape=(), dtype=float32)
# tf.Tensor(82.98387, shape=(), dtype=float32)
# tf.Tensor(141.62311, shape=(), dtype=float32)
# tf.Tensor(78.88237, shape=(), dtype=float32)
# tf.Tensor(90.974434, shape=(), dtype=float32)
# tf.Tensor(100.48385, shape=(), dtype=float32)
# tf.Tensor(112.24448, shape=(), dtype=float32)
# tf.Tensor(134.8656, shape=(), dtype=float32)
# tf.Tensor(124.11122, shape=(), dtype=float32)
# tf.Tensor(103.06352, shape=(), dtype=float32)
# tf.Tensor(110.63753, shape=(), dtype=float32)
# tf.Tensor(105.50842, shape=(), dtype=float32)
# tf.Tensor(58.350647, shape=(), dtype=float32)
# tf.Tensor(81.119675, shape=(), dtype=float32)
# tf.Tensor(60.776222, shape=(), dtype=float32)
# tf.Tensor(63.822666, shape=(), dtype=float32)
# tf.Tensor(112.23685, shape=(), dtype=float32)
# tf.Tensor(154.30647, shape=(), dtype=float32)
# tf.Tensor(72.732925, shape=(), dtype=float32)
# tf.Tensor(111.61316, shape=(), dtype=float32)
# tf.Tensor(111.82783, shape=(), dtype=float32)
# tf.Tensor(107.04042, shape=(), dtype=float32)
# tf.Tensor(113.412994, shape=(), dtype=float32)
# tf.Tensor(115.68497, shape=(), dtype=float32)
# tf.Tensor(111.34166, shape=(), dtype=float32)
# tf.Tensor(114.62272, shape=(), dtype=float32)
# tf.Tensor(94.0235, shape=(), dtype=float32)
# tf.Tensor(87.5838, shape=(), dtype=float32)
# tf.Tensor(74.157, shape=(), dtype=float32)
# tf.Tensor(124.35904, shape=(), dtype=float32)
# tf.Tensor(92.81774, shape=(), dtype=float32)
# tf.Tensor(81.32204, shape=(), dtype=float32)
# tf.Tensor(104.54111, shape=(), dtype=float32)
# tf.Tensor(88.636566, shape=(), dtype=float32)
# tf.Tensor(94.056145, shape=(), dtype=float32)
# tf.Tensor(71.241165, shape=(), dtype=float32)
# tf.Tensor(99.34235, shape=(), dtype=float32)
# tf.Tensor(136.4023, shape=(), dtype=float32)
# tf.Tensor(87.598816, shape=(), dtype=float32)
# tf.Tensor(109.573105, shape=(), dtype=float32)
# tf.Tensor(76.86743, shape=(), dtype=float32)
# tf.Tensor(88.14603, shape=(), dtype=float32)
# tf.Tensor(87.65654, shape=(), dtype=float32)
# tf.Tensor(97.03725, shape=(), dtype=float32)
# tf.Tensor(98.919395, shape=(), dtype=float32)
# tf.Tensor(99.320816, shape=(), dtype=float32)
# tf.Tensor(128.3554, shape=(), dtype=float32)
# tf.Tensor(95.6464, shape=(), dtype=float32)
# tf.Tensor(90.58009, shape=(), dtype=float32)
# tf.Tensor(113.76254, shape=(), dtype=float32)
# tf.Tensor(103.722, shape=(), dtype=float32)
# tf.Tensor(107.61647, shape=(), dtype=float32)
# tf.Tensor(69.47876, shape=(), dtype=float32)
# tf.Tensor(134.06868, shape=(), dtype=float32)
# tf.Tensor(58.614777, shape=(), dtype=float32)
# tf.Tensor(109.89914, shape=(), dtype=float32)
# tf.Tensor(77.823, shape=(), dtype=float32)
# tf.Tensor(90.64351, shape=(), dtype=float32)
# tf.Tensor(63.68029, shape=(), dtype=float32)
# tf.Tensor(107.78108, shape=(), dtype=float32)
# tf.Tensor(106.44963, shape=(), dtype=float32)
# tf.Tensor(106.5616, shape=(), dtype=float32)
# tf.Tensor(124.24675, shape=(), dtype=float32)
# tf.Tensor(92.02182, shape=(), dtype=float32)
# tf.Tensor(87.37364, shape=(), dtype=float32)
# tf.Tensor(104.60954, shape=(), dtype=float32)
# tf.Tensor(56.23076, shape=(), dtype=float32)
# tf.Tensor(88.38613, shape=(), dtype=float32)
# tf.Tensor(100.56442, shape=(), dtype=float32)
# tf.Tensor(92.388115, shape=(), dtype=float32)
# tf.Tensor(113.2816, shape=(), dtype=float32)
# tf.Tensor(90.07696, shape=(), dtype=float32)
# tf.Tensor(80.21783, shape=(), dtype=float32)
# tf.Tensor(97.61342, shape=(), dtype=float32)
# tf.Tensor(100.31268, shape=(), dtype=float32)
# tf.Tensor(85.69062, shape=(), dtype=float32)
# tf.Tensor(64.16669, shape=(), dtype=float32)
# tf.Tensor(49.181534, shape=(), dtype=float32)
# tf.Tensor(69.74301, shape=(), dtype=float32)
# tf.Tensor(132.55032, shape=(), dtype=float32)
# tf.Tensor(140.42159, shape=(), dtype=float32)
# tf.Tensor(97.28681, shape=(), dtype=float32)
# tf.Tensor(76.20014, shape=(), dtype=float32)
# tf.Tensor(69.25156, shape=(), dtype=float32)
# tf.Tensor(101.795425, shape=(), dtype=float32)
# tf.Tensor(87.82167, shape=(), dtype=float32)
# tf.Tensor(84.589516, shape=(), dtype=float32)
# tf.Tensor(82.88429, shape=(), dtype=float32)
# tf.Tensor(137.7395, shape=(), dtype=float32)
# tf.Tensor(77.10391, shape=(), dtype=float32)
# tf.Tensor(101.622154, shape=(), dtype=float32)
# tf.Tensor(80.4029, shape=(), dtype=float32)
# tf.Tensor(74.4474, shape=(), dtype=float32)
# tf.Tensor(93.22308, shape=(), dtype=float32)
# tf.Tensor(89.76281, shape=(), dtype=float32)
# tf.Tensor(88.92981, shape=(), dtype=float32)
# tf.Tensor(81.42087, shape=(), dtype=float32)
# tf.Tensor(109.674484, shape=(), dtype=float32)
# tf.Tensor(104.612465, shape=(), dtype=float32)
# tf.Tensor(89.68458, shape=(), dtype=float32)
# tf.Tensor(69.75559, shape=(), dtype=float32)
# tf.Tensor(55.01032, shape=(), dtype=float32)
# tf.Tensor(73.58188, shape=(), dtype=float32)
# tf.Tensor(60.428955, shape=(), dtype=float32)
# tf.Tensor(121.27072, shape=(), dtype=float32)
# tf.Tensor(93.69077, shape=(), dtype=float32)
# tf.Tensor(79.00047, shape=(), dtype=float32)
# tf.Tensor(93.06737, shape=(), dtype=float32)
# tf.Tensor(80.653656, shape=(), dtype=float32)
# tf.Tensor(97.77698, shape=(), dtype=float32)
# tf.Tensor(97.36847, shape=(), dtype=float32)
# tf.Tensor(117.82892, shape=(), dtype=float32)
# tf.Tensor(84.1057, shape=(), dtype=float32)
# tf.Tensor(105.118286, shape=(), dtype=float32)
# tf.Tensor(80.05333, shape=(), dtype=float32)
# tf.Tensor(75.0878, shape=(), dtype=float32)
# tf.Tensor(89.307434, shape=(), dtype=float32)
# tf.Tensor(103.206024, shape=(), dtype=float32)
# tf.Tensor(82.10129, shape=(), dtype=float32)
# tf.Tensor(71.51303, shape=(), dtype=float32)
# tf.Tensor(46.661575, shape=(), dtype=float32)
# tf.Tensor(79.77633, shape=(), dtype=float32)
# tf.Tensor(100.9978, shape=(), dtype=float32)
# tf.Tensor(72.673904, shape=(), dtype=float32)
# tf.Tensor(74.76072, shape=(), dtype=float32)
# tf.Tensor(93.82257, shape=(), dtype=float32)
# tf.Tensor(102.000984, shape=(), dtype=float32)
# tf.Tensor(96.10243, shape=(), dtype=float32)
# tf.Tensor(86.00552, shape=(), dtype=float32)
# tf.Tensor(70.432014, shape=(), dtype=float32)
# tf.Tensor(74.689316, shape=(), dtype=float32)
# tf.Tensor(72.67081, shape=(), dtype=float32)
# tf.Tensor(109.071625, shape=(), dtype=float32)
# tf.Tensor(114.67572, shape=(), dtype=float32)
# tf.Tensor(114.37537, shape=(), dtype=float32)
# tf.Tensor(73.53789, shape=(), dtype=float32)
# tf.Tensor(83.66181, shape=(), dtype=float32)
# tf.Tensor(107.50391, shape=(), dtype=float32)
# tf.Tensor(81.88606, shape=(), dtype=float32)
# tf.Tensor(91.41713, shape=(), dtype=float32)
# tf.Tensor(104.40209, shape=(), dtype=float32)
# tf.Tensor(88.39517, shape=(), dtype=float32)
# tf.Tensor(98.467476, shape=(), dtype=float32)
# tf.Tensor(80.19316, shape=(), dtype=float32)
# tf.Tensor(79.052, shape=(), dtype=float32)
# tf.Tensor(68.2823, shape=(), dtype=float32)
# tf.Tensor(94.373886, shape=(), dtype=float32)
# tf.Tensor(106.77358, shape=(), dtype=float32)
# tf.Tensor(102.40224, shape=(), dtype=float32)
# tf.Tensor(64.87982, shape=(), dtype=float32)
# tf.Tensor(97.170654, shape=(), dtype=float32)
# tf.Tensor(62.80461, shape=(), dtype=float32)
# tf.Tensor(72.34634, shape=(), dtype=float32)
# tf.Tensor(81.49893, shape=(), dtype=float32)
# tf.Tensor(81.412025, shape=(), dtype=float32)
# tf.Tensor(85.684296, shape=(), dtype=float32)
# tf.Tensor(93.22989, shape=(), dtype=float32)
# tf.Tensor(74.024475, shape=(), dtype=float32)
# tf.Tensor(85.54287, shape=(), dtype=float32)
# tf.Tensor(47.763313, shape=(), dtype=float32)
# tf.Tensor(80.03409, shape=(), dtype=float32)
# tf.Tensor(110.7553, shape=(), dtype=float32)
# tf.Tensor(107.1712, shape=(), dtype=float32)
# tf.Tensor(126.42848, shape=(), dtype=float32)
# tf.Tensor(135.62646, shape=(), dtype=float32)
# tf.Tensor(80.50165, shape=(), dtype=float32)
# tf.Tensor(93.75484, shape=(), dtype=float32)
# tf.Tensor(87.83115, shape=(), dtype=float32)
# tf.Tensor(80.431946, shape=(), dtype=float32)
# tf.Tensor(112.92961, shape=(), dtype=float32)
# tf.Tensor(94.60376, shape=(), dtype=float32)
# tf.Tensor(110.2373, shape=(), dtype=float32)
# tf.Tensor(99.80843, shape=(), dtype=float32)
# tf.Tensor(124.5668, shape=(), dtype=float32)
# tf.Tensor(92.5231, shape=(), dtype=float32)
# tf.Tensor(118.56548, shape=(), dtype=float32)
# tf.Tensor(58.143024, shape=(), dtype=float32)
# tf.Tensor(44.065414, shape=(), dtype=float32)
# tf.Tensor(90.85474, shape=(), dtype=float32)
# tf.Tensor(61.119995, shape=(), dtype=float32)
# tf.Tensor(114.95615, shape=(), dtype=float32)
# tf.Tensor(164.12262, shape=(), dtype=float32)
# tf.Tensor(90.65229, shape=(), dtype=float32)
# tf.Tensor(96.61626, shape=(), dtype=float32)
# tf.Tensor(74.759766, shape=(), dtype=float32)
# tf.Tensor(76.81617, shape=(), dtype=float32)
# tf.Tensor(60.580643, shape=(), dtype=float32)
# tf.Tensor(75.57102, shape=(), dtype=float32)
# tf.Tensor(94.78285, shape=(), dtype=float32)
# tf.Tensor(124.84219, shape=(), dtype=float32)
# tf.Tensor(76.12057, shape=(), dtype=float32)
# tf.Tensor(83.71298, shape=(), dtype=float32)
# tf.Tensor(82.1724, shape=(), dtype=float32)
# tf.Tensor(56.92449, shape=(), dtype=float32)
# tf.Tensor(88.40419, shape=(), dtype=float32)
# tf.Tensor(117.117325, shape=(), dtype=float32)
# tf.Tensor(77.35797, shape=(), dtype=float32)
# tf.Tensor(71.31927, shape=(), dtype=float32)
# tf.Tensor(80.26128, shape=(), dtype=float32)
# tf.Tensor(108.54877, shape=(), dtype=float32)
# tf.Tensor(97.72618, shape=(), dtype=float32)
# tf.Tensor(84.78517, shape=(), dtype=float32)
# tf.Tensor(89.52572, shape=(), dtype=float32)
# tf.Tensor(76.2399, shape=(), dtype=float32)
# tf.Tensor(70.37533, shape=(), dtype=float32)
# tf.Tensor(74.75845, shape=(), dtype=float32)
# tf.Tensor(70.22362, shape=(), dtype=float32)
# tf.Tensor(97.439285, shape=(), dtype=float32)
# tf.Tensor(94.31073, shape=(), dtype=float32)
# tf.Tensor(123.399765, shape=(), dtype=float32)
# tf.Tensor(68.76819, shape=(), dtype=float32)
# tf.Tensor(78.845985, shape=(), dtype=float32)
# tf.Tensor(100.696236, shape=(), dtype=float32)
# tf.Tensor(64.84854, shape=(), dtype=float32)
# tf.Tensor(74.471054, shape=(), dtype=float32)
# tf.Tensor(97.37495, shape=(), dtype=float32)
# tf.Tensor(90.013794, shape=(), dtype=float32)
# tf.Tensor(75.6486, shape=(), dtype=float32)
# tf.Tensor(70.91004, shape=(), dtype=float32)
# tf.Tensor(83.438644, shape=(), dtype=float32)
# tf.Tensor(71.814865, shape=(), dtype=float32)
# tf.Tensor(92.16507, shape=(), dtype=float32)
# tf.Tensor(79.86354, shape=(), dtype=float32)
# tf.Tensor(75.34629, shape=(), dtype=float32)
# tf.Tensor(77.94464, shape=(), dtype=float32)
# tf.Tensor(62.304108, shape=(), dtype=float32)
# tf.Tensor(73.433235, shape=(), dtype=float32)
# tf.Tensor(122.95636, shape=(), dtype=float32)
# tf.Tensor(63.09108, shape=(), dtype=float32)
# tf.Tensor(94.16048, shape=(), dtype=float32)
# tf.Tensor(107.842384, shape=(), dtype=float32)
# tf.Tensor(107.27861, shape=(), dtype=float32)
# Train Epoch 1 Loss 106.8148
# Saving checkpoint for epoch 1 at trSfor3/cp.ckpt
# Valid prec 0.3063 recall 0.8657 AUC 0.8899, acc 0.7671
# Time taken for 1 epoch: 6165.584811210632 secs
#
# tf.Tensor(87.259964, shape=(), dtype=float32)
# tf.Tensor(80.141785, shape=(), dtype=float32)
# tf.Tensor(83.37102, shape=(), dtype=float32)
# tf.Tensor(91.98248, shape=(), dtype=float32)
# tf.Tensor(111.263626, shape=(), dtype=float32)
# tf.Tensor(78.61925, shape=(), dtype=float32)
# tf.Tensor(99.51889, shape=(), dtype=float32)
# tf.Tensor(105.61728, shape=(), dtype=float32)
# tf.Tensor(72.334076, shape=(), dtype=float32)
# tf.Tensor(111.83719, shape=(), dtype=float32)
# tf.Tensor(79.77105, shape=(), dtype=float32)
# tf.Tensor(91.271484, shape=(), dtype=float32)
# tf.Tensor(64.30856, shape=(), dtype=float32)
# tf.Tensor(141.79022, shape=(), dtype=float32)
# tf.Tensor(89.8278, shape=(), dtype=float32)
# tf.Tensor(108.11421, shape=(), dtype=float32)
# tf.Tensor(106.21184, shape=(), dtype=float32)
# tf.Tensor(80.524376, shape=(), dtype=float32)
# tf.Tensor(63.63382, shape=(), dtype=float32)
# tf.Tensor(97.195526, shape=(), dtype=float32)
# tf.Tensor(78.57902, shape=(), dtype=float32)
# tf.Tensor(81.81508, shape=(), dtype=float32)
# tf.Tensor(107.773224, shape=(), dtype=float32)
# tf.Tensor(92.900925, shape=(), dtype=float32)
# tf.Tensor(60.88818, shape=(), dtype=float32)
# tf.Tensor(91.23137, shape=(), dtype=float32)
# tf.Tensor(93.60764, shape=(), dtype=float32)
# tf.Tensor(74.71092, shape=(), dtype=float32)
# tf.Tensor(55.00583, shape=(), dtype=float32)
# tf.Tensor(81.038284, shape=(), dtype=float32)
# tf.Tensor(99.69429, shape=(), dtype=float32)
# tf.Tensor(101.64105, shape=(), dtype=float32)
# tf.Tensor(98.07687, shape=(), dtype=float32)
# tf.Tensor(48.014496, shape=(), dtype=float32)
# tf.Tensor(109.784546, shape=(), dtype=float32)
# tf.Tensor(85.843925, shape=(), dtype=float32)
# tf.Tensor(99.34266, shape=(), dtype=float32)
# tf.Tensor(81.81589, shape=(), dtype=float32)
# tf.Tensor(72.55492, shape=(), dtype=float32)
# tf.Tensor(66.33466, shape=(), dtype=float32)
# tf.Tensor(79.15845, shape=(), dtype=float32)
# tf.Tensor(58.419594, shape=(), dtype=float32)
# tf.Tensor(108.73539, shape=(), dtype=float32)
# tf.Tensor(50.290417, shape=(), dtype=float32)
# tf.Tensor(59.8366, shape=(), dtype=float32)
# tf.Tensor(114.39494, shape=(), dtype=float32)
# tf.Tensor(132.84927, shape=(), dtype=float32)
# tf.Tensor(66.28755, shape=(), dtype=float32)
# tf.Tensor(58.609875, shape=(), dtype=float32)
# tf.Tensor(129.43285, shape=(), dtype=float32)
# tf.Tensor(53.45732, shape=(), dtype=float32)
# tf.Tensor(72.088, shape=(), dtype=float32)
# tf.Tensor(77.56521, shape=(), dtype=float32)
# tf.Tensor(58.633568, shape=(), dtype=float32)
# tf.Tensor(102.02451, shape=(), dtype=float32)
# tf.Tensor(56.396267, shape=(), dtype=float32)
# tf.Tensor(87.77809, shape=(), dtype=float32)
# tf.Tensor(66.19687, shape=(), dtype=float32)
# tf.Tensor(65.88461, shape=(), dtype=float32)
# tf.Tensor(67.44129, shape=(), dtype=float32)
# tf.Tensor(83.968, shape=(), dtype=float32)
# tf.Tensor(58.31456, shape=(), dtype=float32)
# tf.Tensor(114.79909, shape=(), dtype=float32)
# tf.Tensor(93.46498, shape=(), dtype=float32)
# tf.Tensor(82.1593, shape=(), dtype=float32)
# tf.Tensor(92.59912, shape=(), dtype=float32)
# tf.Tensor(96.19532, shape=(), dtype=float32)
# tf.Tensor(60.96286, shape=(), dtype=float32)
# tf.Tensor(72.6104, shape=(), dtype=float32)
# tf.Tensor(93.75459, shape=(), dtype=float32)
# tf.Tensor(74.30995, shape=(), dtype=float32)
# tf.Tensor(45.918304, shape=(), dtype=float32)
# tf.Tensor(64.24907, shape=(), dtype=float32)
# tf.Tensor(68.47713, shape=(), dtype=float32)
# tf.Tensor(73.155914, shape=(), dtype=float32)
# tf.Tensor(64.530495, shape=(), dtype=float32)
# tf.Tensor(82.996735, shape=(), dtype=float32)
# tf.Tensor(105.08737, shape=(), dtype=float32)
# tf.Tensor(56.178658, shape=(), dtype=float32)
# tf.Tensor(58.686226, shape=(), dtype=float32)
# tf.Tensor(71.01153, shape=(), dtype=float32)
# tf.Tensor(77.356094, shape=(), dtype=float32)
# tf.Tensor(72.69301, shape=(), dtype=float32)
# tf.Tensor(80.46371, shape=(), dtype=float32)
# tf.Tensor(50.99525, shape=(), dtype=float32)
# tf.Tensor(80.03808, shape=(), dtype=float32)
# tf.Tensor(101.11098, shape=(), dtype=float32)
# tf.Tensor(61.918484, shape=(), dtype=float32)
# tf.Tensor(70.049416, shape=(), dtype=float32)
# tf.Tensor(73.121994, shape=(), dtype=float32)
# tf.Tensor(76.740105, shape=(), dtype=float32)
# tf.Tensor(64.81097, shape=(), dtype=float32)
# tf.Tensor(88.278465, shape=(), dtype=float32)
# tf.Tensor(60.834965, shape=(), dtype=float32)
# tf.Tensor(95.57298, shape=(), dtype=float32)
# tf.Tensor(56.597084, shape=(), dtype=float32)
# tf.Tensor(51.141228, shape=(), dtype=float32)
# tf.Tensor(75.059875, shape=(), dtype=float32)
# tf.Tensor(64.44893, shape=(), dtype=float32)
# tf.Tensor(70.34121, shape=(), dtype=float32)
# tf.Tensor(59.400505, shape=(), dtype=float32)
# tf.Tensor(53.48803, shape=(), dtype=float32)
# tf.Tensor(82.71834, shape=(), dtype=float32)
# tf.Tensor(48.844772, shape=(), dtype=float32)
# tf.Tensor(70.226105, shape=(), dtype=float32)
# tf.Tensor(50.09573, shape=(), dtype=float32)
# tf.Tensor(49.54601, shape=(), dtype=float32)
# tf.Tensor(90.60724, shape=(), dtype=float32)
# tf.Tensor(110.177216, shape=(), dtype=float32)
# tf.Tensor(48.00634, shape=(), dtype=float32)
# tf.Tensor(79.55026, shape=(), dtype=float32)
# tf.Tensor(71.8769, shape=(), dtype=float32)
# tf.Tensor(59.378597, shape=(), dtype=float32)
# tf.Tensor(50.483624, shape=(), dtype=float32)
# tf.Tensor(89.275314, shape=(), dtype=float32)
# tf.Tensor(77.96325, shape=(), dtype=float32)
# tf.Tensor(54.15197, shape=(), dtype=float32)
# tf.Tensor(94.94551, shape=(), dtype=float32)
# tf.Tensor(79.14504, shape=(), dtype=float32)
# tf.Tensor(59.212753, shape=(), dtype=float32)
# tf.Tensor(74.26277, shape=(), dtype=float32)
# tf.Tensor(56.483246, shape=(), dtype=float32)
# tf.Tensor(66.33594, shape=(), dtype=float32)
# tf.Tensor(94.85933, shape=(), dtype=float32)
# tf.Tensor(56.131218, shape=(), dtype=float32)
# tf.Tensor(100.959885, shape=(), dtype=float32)
# tf.Tensor(66.820274, shape=(), dtype=float32)
# tf.Tensor(90.04363, shape=(), dtype=float32)
# tf.Tensor(91.74785, shape=(), dtype=float32)
# tf.Tensor(74.80617, shape=(), dtype=float32)
# tf.Tensor(79.912544, shape=(), dtype=float32)
# tf.Tensor(68.17676, shape=(), dtype=float32)
# tf.Tensor(66.745415, shape=(), dtype=float32)
# tf.Tensor(88.69872, shape=(), dtype=float32)
# tf.Tensor(48.65227, shape=(), dtype=float32)
# tf.Tensor(64.82307, shape=(), dtype=float32)
# tf.Tensor(56.771027, shape=(), dtype=float32)
# tf.Tensor(83.93441, shape=(), dtype=float32)
# tf.Tensor(74.369385, shape=(), dtype=float32)
# tf.Tensor(53.061287, shape=(), dtype=float32)
# tf.Tensor(68.32999, shape=(), dtype=float32)
# tf.Tensor(69.35579, shape=(), dtype=float32)
# tf.Tensor(65.04147, shape=(), dtype=float32)
# tf.Tensor(49.854652, shape=(), dtype=float32)
# tf.Tensor(53.16059, shape=(), dtype=float32)
# tf.Tensor(71.97716, shape=(), dtype=float32)
# tf.Tensor(51.301117, shape=(), dtype=float32)
# tf.Tensor(46.059715, shape=(), dtype=float32)
# tf.Tensor(75.235214, shape=(), dtype=float32)
# tf.Tensor(86.04062, shape=(), dtype=float32)
# tf.Tensor(60.343372, shape=(), dtype=float32)
# tf.Tensor(81.37816, shape=(), dtype=float32)
# tf.Tensor(41.43809, shape=(), dtype=float32)
# tf.Tensor(76.17003, shape=(), dtype=float32)
# tf.Tensor(58.468475, shape=(), dtype=float32)
# tf.Tensor(48.520447, shape=(), dtype=float32)
# tf.Tensor(95.56722, shape=(), dtype=float32)
# tf.Tensor(58.22852, shape=(), dtype=float32)
# tf.Tensor(39.361908, shape=(), dtype=float32)
# tf.Tensor(62.576397, shape=(), dtype=float32)
# tf.Tensor(46.48391, shape=(), dtype=float32)
# tf.Tensor(84.6687, shape=(), dtype=float32)
# tf.Tensor(60.493206, shape=(), dtype=float32)
# tf.Tensor(58.21123, shape=(), dtype=float32)
# tf.Tensor(57.17421, shape=(), dtype=float32)
# tf.Tensor(68.30721, shape=(), dtype=float32)
# tf.Tensor(44.25618, shape=(), dtype=float32)
# tf.Tensor(70.52109, shape=(), dtype=float32)
# tf.Tensor(65.988464, shape=(), dtype=float32)
# tf.Tensor(69.75395, shape=(), dtype=float32)
# tf.Tensor(28.64209, shape=(), dtype=float32)
# tf.Tensor(61.74624, shape=(), dtype=float32)
# tf.Tensor(65.08247, shape=(), dtype=float32)
# tf.Tensor(56.116405, shape=(), dtype=float32)
# tf.Tensor(82.771194, shape=(), dtype=float32)
# tf.Tensor(53.801815, shape=(), dtype=float32)
# tf.Tensor(43.896065, shape=(), dtype=float32)
# tf.Tensor(102.30115, shape=(), dtype=float32)
# tf.Tensor(49.71814, shape=(), dtype=float32)
# tf.Tensor(86.21248, shape=(), dtype=float32)
# tf.Tensor(56.019196, shape=(), dtype=float32)
# tf.Tensor(75.84587, shape=(), dtype=float32)
# tf.Tensor(54.046158, shape=(), dtype=float32)
# tf.Tensor(56.267197, shape=(), dtype=float32)
# tf.Tensor(82.03212, shape=(), dtype=float32)
# tf.Tensor(70.230484, shape=(), dtype=float32)
# tf.Tensor(67.6698, shape=(), dtype=float32)
# tf.Tensor(59.410034, shape=(), dtype=float32)
# tf.Tensor(89.179794, shape=(), dtype=float32)
# tf.Tensor(58.271767, shape=(), dtype=float32)
# tf.Tensor(40.91303, shape=(), dtype=float32)
# tf.Tensor(75.056175, shape=(), dtype=float32)
# tf.Tensor(59.681244, shape=(), dtype=float32)
# tf.Tensor(83.30755, shape=(), dtype=float32)
# tf.Tensor(51.773773, shape=(), dtype=float32)
# tf.Tensor(72.45819, shape=(), dtype=float32)
# tf.Tensor(87.01189, shape=(), dtype=float32)
# tf.Tensor(78.04338, shape=(), dtype=float32)
# tf.Tensor(60.78921, shape=(), dtype=float32)
# tf.Tensor(51.301376, shape=(), dtype=float32)
# tf.Tensor(51.2752, shape=(), dtype=float32)
# tf.Tensor(61.000404, shape=(), dtype=float32)
# tf.Tensor(77.7734, shape=(), dtype=float32)
# tf.Tensor(48.90483, shape=(), dtype=float32)
# tf.Tensor(53.070538, shape=(), dtype=float32)
# tf.Tensor(71.89762, shape=(), dtype=float32)
# tf.Tensor(86.262726, shape=(), dtype=float32)
# tf.Tensor(51.443596, shape=(), dtype=float32)
# tf.Tensor(48.469105, shape=(), dtype=float32)
# tf.Tensor(142.9119, shape=(), dtype=float32)
# tf.Tensor(75.23687, shape=(), dtype=float32)
# tf.Tensor(95.78511, shape=(), dtype=float32)
# tf.Tensor(73.97114, shape=(), dtype=float32)
# tf.Tensor(75.29584, shape=(), dtype=float32)
# tf.Tensor(46.97873, shape=(), dtype=float32)
# tf.Tensor(76.40439, shape=(), dtype=float32)
# tf.Tensor(64.8063, shape=(), dtype=float32)
# tf.Tensor(49.735134, shape=(), dtype=float32)
# tf.Tensor(67.67959, shape=(), dtype=float32)
# tf.Tensor(57.055172, shape=(), dtype=float32)
# tf.Tensor(53.40905, shape=(), dtype=float32)
# tf.Tensor(77.31747, shape=(), dtype=float32)
# tf.Tensor(58.597847, shape=(), dtype=float32)
# tf.Tensor(88.37606, shape=(), dtype=float32)
# tf.Tensor(51.546417, shape=(), dtype=float32)
# tf.Tensor(82.90921, shape=(), dtype=float32)
# tf.Tensor(76.306305, shape=(), dtype=float32)
# tf.Tensor(54.81696, shape=(), dtype=float32)
# tf.Tensor(44.949913, shape=(), dtype=float32)
# tf.Tensor(45.690132, shape=(), dtype=float32)
# tf.Tensor(74.14337, shape=(), dtype=float32)
# tf.Tensor(55.6094, shape=(), dtype=float32)
# tf.Tensor(61.65303, shape=(), dtype=float32)
# tf.Tensor(60.750183, shape=(), dtype=float32)
# tf.Tensor(68.15048, shape=(), dtype=float32)
# tf.Tensor(51.800224, shape=(), dtype=float32)
# tf.Tensor(55.573654, shape=(), dtype=float32)
# tf.Tensor(57.506714, shape=(), dtype=float32)
# tf.Tensor(49.504604, shape=(), dtype=float32)
# tf.Tensor(41.514175, shape=(), dtype=float32)
# tf.Tensor(72.945145, shape=(), dtype=float32)
# tf.Tensor(117.381134, shape=(), dtype=float32)
# tf.Tensor(48.635704, shape=(), dtype=float32)
# tf.Tensor(62.48166, shape=(), dtype=float32)
# tf.Tensor(41.106297, shape=(), dtype=float32)
# tf.Tensor(53.31897, shape=(), dtype=float32)
# tf.Tensor(54.326866, shape=(), dtype=float32)
# tf.Tensor(60.222298, shape=(), dtype=float32)
# tf.Tensor(85.90723, shape=(), dtype=float32)
# tf.Tensor(93.93161, shape=(), dtype=float32)
# tf.Tensor(58.91736, shape=(), dtype=float32)
# tf.Tensor(68.95882, shape=(), dtype=float32)
# tf.Tensor(56.187454, shape=(), dtype=float32)
# tf.Tensor(67.96338, shape=(), dtype=float32)
# tf.Tensor(56.82176, shape=(), dtype=float32)
# tf.Tensor(56.274506, shape=(), dtype=float32)
# tf.Tensor(73.21915, shape=(), dtype=float32)
# tf.Tensor(71.72033, shape=(), dtype=float32)
# tf.Tensor(64.31346, shape=(), dtype=float32)
# tf.Tensor(46.958572, shape=(), dtype=float32)
# tf.Tensor(100.91701, shape=(), dtype=float32)
# tf.Tensor(61.15493, shape=(), dtype=float32)
# tf.Tensor(36.935234, shape=(), dtype=float32)
# tf.Tensor(109.680725, shape=(), dtype=float32)
# tf.Tensor(48.227448, shape=(), dtype=float32)
# tf.Tensor(107.95061, shape=(), dtype=float32)
# tf.Tensor(56.026752, shape=(), dtype=float32)
# tf.Tensor(62.371456, shape=(), dtype=float32)
# tf.Tensor(83.211754, shape=(), dtype=float32)
# tf.Tensor(52.801765, shape=(), dtype=float32)
# tf.Tensor(61.303295, shape=(), dtype=float32)
# tf.Tensor(50.266106, shape=(), dtype=float32)
# tf.Tensor(80.0603, shape=(), dtype=float32)
# tf.Tensor(70.09575, shape=(), dtype=float32)
# tf.Tensor(62.354843, shape=(), dtype=float32)
# tf.Tensor(52.70651, shape=(), dtype=float32)
# tf.Tensor(77.15567, shape=(), dtype=float32)
# tf.Tensor(58.039093, shape=(), dtype=float32)
# tf.Tensor(91.78341, shape=(), dtype=float32)
# tf.Tensor(43.018307, shape=(), dtype=float32)
# tf.Tensor(155.658, shape=(), dtype=float32)
# tf.Tensor(81.406975, shape=(), dtype=float32)
# tf.Tensor(46.73593, shape=(), dtype=float32)
# tf.Tensor(35.348793, shape=(), dtype=float32)
# tf.Tensor(44.00555, shape=(), dtype=float32)
# tf.Tensor(71.7166, shape=(), dtype=float32)
# tf.Tensor(71.97444, shape=(), dtype=float32)
# tf.Tensor(86.595856, shape=(), dtype=float32)
# tf.Tensor(74.493744, shape=(), dtype=float32)
# tf.Tensor(70.72781, shape=(), dtype=float32)
# tf.Tensor(60.464684, shape=(), dtype=float32)
# tf.Tensor(65.08142, shape=(), dtype=float32)
# tf.Tensor(52.43878, shape=(), dtype=float32)
# tf.Tensor(60.18241, shape=(), dtype=float32)
# tf.Tensor(48.177933, shape=(), dtype=float32)
# tf.Tensor(56.31403, shape=(), dtype=float32)
# tf.Tensor(58.5069, shape=(), dtype=float32)
# tf.Tensor(67.58234, shape=(), dtype=float32)
# tf.Tensor(84.007835, shape=(), dtype=float32)
# tf.Tensor(76.16936, shape=(), dtype=float32)
# tf.Tensor(49.510803, shape=(), dtype=float32)
# tf.Tensor(62.190987, shape=(), dtype=float32)
# tf.Tensor(70.24202, shape=(), dtype=float32)
# tf.Tensor(81.57374, shape=(), dtype=float32)
# tf.Tensor(76.52928, shape=(), dtype=float32)
# tf.Tensor(85.70647, shape=(), dtype=float32)
# tf.Tensor(128.172, shape=(), dtype=float32)
# tf.Tensor(105.25267, shape=(), dtype=float32)
# tf.Tensor(43.322113, shape=(), dtype=float32)
# tf.Tensor(60.832336, shape=(), dtype=float32)
# tf.Tensor(54.20804, shape=(), dtype=float32)
# tf.Tensor(51.83237, shape=(), dtype=float32)
# tf.Tensor(40.769905, shape=(), dtype=float32)
# tf.Tensor(74.770645, shape=(), dtype=float32)
# tf.Tensor(56.53083, shape=(), dtype=float32)
# tf.Tensor(48.059685, shape=(), dtype=float32)
# tf.Tensor(59.7884, shape=(), dtype=float32)
# tf.Tensor(55.209282, shape=(), dtype=float32)
# tf.Tensor(55.001175, shape=(), dtype=float32)
# tf.Tensor(34.03901, shape=(), dtype=float32)
# tf.Tensor(72.44, shape=(), dtype=float32)
# tf.Tensor(37.70854, shape=(), dtype=float32)
# tf.Tensor(68.87335, shape=(), dtype=float32)
# tf.Tensor(93.53389, shape=(), dtype=float32)
# tf.Tensor(70.05801, shape=(), dtype=float32)
# tf.Tensor(75.829575, shape=(), dtype=float32)
# tf.Tensor(70.76297, shape=(), dtype=float32)
# tf.Tensor(63.79445, shape=(), dtype=float32)
# tf.Tensor(65.61336, shape=(), dtype=float32)
# tf.Tensor(60.836777, shape=(), dtype=float32)
# tf.Tensor(65.93622, shape=(), dtype=float32)
# tf.Tensor(57.383858, shape=(), dtype=float32)
# tf.Tensor(47.91787, shape=(), dtype=float32)
# tf.Tensor(53.177437, shape=(), dtype=float32)
# tf.Tensor(44.892845, shape=(), dtype=float32)
# tf.Tensor(54.04973, shape=(), dtype=float32)
# tf.Tensor(108.51767, shape=(), dtype=float32)
# tf.Tensor(56.607533, shape=(), dtype=float32)
# tf.Tensor(81.13063, shape=(), dtype=float32)
# tf.Tensor(87.53145, shape=(), dtype=float32)
# tf.Tensor(63.803944, shape=(), dtype=float32)
# tf.Tensor(100.55258, shape=(), dtype=float32)
# tf.Tensor(58.525433, shape=(), dtype=float32)
# tf.Tensor(69.01044, shape=(), dtype=float32)
# tf.Tensor(61.288895, shape=(), dtype=float32)
# tf.Tensor(75.41272, shape=(), dtype=float32)
# tf.Tensor(118.68915, shape=(), dtype=float32)
# tf.Tensor(75.20601, shape=(), dtype=float32)
# tf.Tensor(99.71611, shape=(), dtype=float32)
# tf.Tensor(62.053154, shape=(), dtype=float32)
# tf.Tensor(50.168884, shape=(), dtype=float32)
# tf.Tensor(35.45883, shape=(), dtype=float32)
# tf.Tensor(53.906895, shape=(), dtype=float32)
# tf.Tensor(63.15715, shape=(), dtype=float32)
# tf.Tensor(43.951584, shape=(), dtype=float32)
# tf.Tensor(61.47726, shape=(), dtype=float32)
# tf.Tensor(97.89244, shape=(), dtype=float32)
# tf.Tensor(46.673546, shape=(), dtype=float32)
# tf.Tensor(40.54821, shape=(), dtype=float32)
# tf.Tensor(50.245743, shape=(), dtype=float32)
# tf.Tensor(60.21395, shape=(), dtype=float32)
# tf.Tensor(46.57074, shape=(), dtype=float32)
# tf.Tensor(48.395638, shape=(), dtype=float32)
# tf.Tensor(40.159664, shape=(), dtype=float32)
# tf.Tensor(50.6907, shape=(), dtype=float32)
# tf.Tensor(68.48407, shape=(), dtype=float32)
# tf.Tensor(50.89778, shape=(), dtype=float32)
# tf.Tensor(38.841053, shape=(), dtype=float32)
# tf.Tensor(54.415756, shape=(), dtype=float32)
# tf.Tensor(47.659294, shape=(), dtype=float32)
# tf.Tensor(55.493195, shape=(), dtype=float32)
# tf.Tensor(89.115135, shape=(), dtype=float32)
# tf.Tensor(49.506287, shape=(), dtype=float32)
# tf.Tensor(23.57691, shape=(), dtype=float32)
# tf.Tensor(71.24538, shape=(), dtype=float32)
# tf.Tensor(34.781548, shape=(), dtype=float32)
# tf.Tensor(65.59027, shape=(), dtype=float32)
# tf.Tensor(48.080044, shape=(), dtype=float32)
# tf.Tensor(62.712463, shape=(), dtype=float32)
# tf.Tensor(61.753532, shape=(), dtype=float32)
# tf.Tensor(75.36418, shape=(), dtype=float32)
# tf.Tensor(83.90724, shape=(), dtype=float32)
# tf.Tensor(39.38424, shape=(), dtype=float32)
# tf.Tensor(49.05574, shape=(), dtype=float32)
# tf.Tensor(45.321045, shape=(), dtype=float32)
# tf.Tensor(48.877422, shape=(), dtype=float32)
# tf.Tensor(36.710953, shape=(), dtype=float32)
# tf.Tensor(70.0196, shape=(), dtype=float32)
# tf.Tensor(58.235905, shape=(), dtype=float32)
# tf.Tensor(40.796463, shape=(), dtype=float32)
# tf.Tensor(42.83571, shape=(), dtype=float32)
# tf.Tensor(56.709625, shape=(), dtype=float32)
# tf.Tensor(77.25383, shape=(), dtype=float32)
# tf.Tensor(55.18802, shape=(), dtype=float32)
# tf.Tensor(26.565434, shape=(), dtype=float32)
# tf.Tensor(26.122429, shape=(), dtype=float32)
# tf.Tensor(28.541096, shape=(), dtype=float32)
# tf.Tensor(70.02979, shape=(), dtype=float32)
# tf.Tensor(74.67084, shape=(), dtype=float32)
# tf.Tensor(69.40522, shape=(), dtype=float32)
# tf.Tensor(42.90999, shape=(), dtype=float32)
# tf.Tensor(62.84428, shape=(), dtype=float32)
# tf.Tensor(68.70744, shape=(), dtype=float32)
# tf.Tensor(72.57789, shape=(), dtype=float32)
# tf.Tensor(54.662125, shape=(), dtype=float32)
# tf.Tensor(52.55571, shape=(), dtype=float32)
# tf.Tensor(55.485313, shape=(), dtype=float32)
# tf.Tensor(94.0275, shape=(), dtype=float32)
# tf.Tensor(84.54704, shape=(), dtype=float32)
# tf.Tensor(85.29703, shape=(), dtype=float32)
# tf.Tensor(76.50421, shape=(), dtype=float32)
# tf.Tensor(39.737686, shape=(), dtype=float32)
# tf.Tensor(44.97746, shape=(), dtype=float32)
# tf.Tensor(61.37805, shape=(), dtype=float32)
# tf.Tensor(74.49161, shape=(), dtype=float32)
# tf.Tensor(31.603676, shape=(), dtype=float32)
# tf.Tensor(50.39189, shape=(), dtype=float32)
# tf.Tensor(30.245075, shape=(), dtype=float32)
# tf.Tensor(127.949585, shape=(), dtype=float32)
# tf.Tensor(64.66802, shape=(), dtype=float32)
# tf.Tensor(42.58687, shape=(), dtype=float32)
# tf.Tensor(52.099606, shape=(), dtype=float32)
# tf.Tensor(48.185875, shape=(), dtype=float32)
# tf.Tensor(48.270065, shape=(), dtype=float32)
# tf.Tensor(69.85444, shape=(), dtype=float32)
# tf.Tensor(58.22861, shape=(), dtype=float32)
# tf.Tensor(68.74365, shape=(), dtype=float32)
# tf.Tensor(59.853214, shape=(), dtype=float32)
# tf.Tensor(103.38609, shape=(), dtype=float32)
# tf.Tensor(61.328423, shape=(), dtype=float32)
# tf.Tensor(71.94821, shape=(), dtype=float32)
# tf.Tensor(48.136993, shape=(), dtype=float32)
# tf.Tensor(78.79113, shape=(), dtype=float32)
# tf.Tensor(44.89233, shape=(), dtype=float32)
# tf.Tensor(74.8513, shape=(), dtype=float32)
# tf.Tensor(52.324184, shape=(), dtype=float32)
# tf.Tensor(40.25613, shape=(), dtype=float32)
# tf.Tensor(57.5839, shape=(), dtype=float32)
# tf.Tensor(56.434944, shape=(), dtype=float32)
# tf.Tensor(69.57175, shape=(), dtype=float32)
# tf.Tensor(52.468445, shape=(), dtype=float32)
# tf.Tensor(60.84298, shape=(), dtype=float32)
# tf.Tensor(69.14661, shape=(), dtype=float32)
# tf.Tensor(51.51621, shape=(), dtype=float32)
# tf.Tensor(41.23027, shape=(), dtype=float32)
# tf.Tensor(45.765984, shape=(), dtype=float32)
# tf.Tensor(75.682785, shape=(), dtype=float32)
# tf.Tensor(37.082455, shape=(), dtype=float32)
# tf.Tensor(65.28319, shape=(), dtype=float32)
# tf.Tensor(35.95086, shape=(), dtype=float32)
# tf.Tensor(40.514473, shape=(), dtype=float32)
# tf.Tensor(66.31444, shape=(), dtype=float32)
# tf.Tensor(75.537315, shape=(), dtype=float32)
# tf.Tensor(34.458527, shape=(), dtype=float32)
# tf.Tensor(52.82769, shape=(), dtype=float32)
# tf.Tensor(35.22443, shape=(), dtype=float32)
# tf.Tensor(29.573841, shape=(), dtype=float32)
# tf.Tensor(49.904907, shape=(), dtype=float32)
# tf.Tensor(86.80209, shape=(), dtype=float32)
# tf.Tensor(40.602673, shape=(), dtype=float32)
# tf.Tensor(30.400536, shape=(), dtype=float32)
# tf.Tensor(37.60389, shape=(), dtype=float32)
# tf.Tensor(72.27871, shape=(), dtype=float32)
# tf.Tensor(45.530556, shape=(), dtype=float32)
# tf.Tensor(51.33645, shape=(), dtype=float32)
# tf.Tensor(28.67313, shape=(), dtype=float32)
# tf.Tensor(50.023094, shape=(), dtype=float32)
# tf.Tensor(77.58188, shape=(), dtype=float32)
# tf.Tensor(60.054703, shape=(), dtype=float32)
# tf.Tensor(63.069656, shape=(), dtype=float32)
# tf.Tensor(56.709084, shape=(), dtype=float32)
# tf.Tensor(41.561733, shape=(), dtype=float32)
# tf.Tensor(51.15262, shape=(), dtype=float32)
# tf.Tensor(36.37231, shape=(), dtype=float32)
# tf.Tensor(73.38821, shape=(), dtype=float32)
# tf.Tensor(38.69492, shape=(), dtype=float32)
# tf.Tensor(68.55342, shape=(), dtype=float32)
# tf.Tensor(38.854027, shape=(), dtype=float32)
# tf.Tensor(29.264685, shape=(), dtype=float32)
# tf.Tensor(79.86228, shape=(), dtype=float32)
# tf.Tensor(31.110966, shape=(), dtype=float32)
# tf.Tensor(56.90558, shape=(), dtype=float32)
# tf.Tensor(32.053627, shape=(), dtype=float32)
# tf.Tensor(65.83451, shape=(), dtype=float32)
# tf.Tensor(48.82391, shape=(), dtype=float32)
# tf.Tensor(67.815125, shape=(), dtype=float32)
# tf.Tensor(40.951546, shape=(), dtype=float32)
# tf.Tensor(43.46059, shape=(), dtype=float32)
# tf.Tensor(49.55293, shape=(), dtype=float32)
# tf.Tensor(64.45483, shape=(), dtype=float32)
# tf.Tensor(52.893616, shape=(), dtype=float32)
# tf.Tensor(31.937704, shape=(), dtype=float32)
# tf.Tensor(47.27214, shape=(), dtype=float32)
# tf.Tensor(31.80654, shape=(), dtype=float32)
# tf.Tensor(56.69519, shape=(), dtype=float32)
# tf.Tensor(52.553802, shape=(), dtype=float32)
# tf.Tensor(64.69839, shape=(), dtype=float32)
# tf.Tensor(39.874863, shape=(), dtype=float32)
# tf.Tensor(43.353153, shape=(), dtype=float32)
# tf.Tensor(39.165497, shape=(), dtype=float32)
# tf.Tensor(25.908916, shape=(), dtype=float32)
# tf.Tensor(22.868393, shape=(), dtype=float32)
# tf.Tensor(84.66845, shape=(), dtype=float32)
# tf.Tensor(76.844894, shape=(), dtype=float32)
# tf.Tensor(38.101162, shape=(), dtype=float32)
# tf.Tensor(47.11406, shape=(), dtype=float32)
# tf.Tensor(41.376366, shape=(), dtype=float32)
# tf.Tensor(61.68655, shape=(), dtype=float32)
# tf.Tensor(115.65834, shape=(), dtype=float32)
# tf.Tensor(43.928715, shape=(), dtype=float32)
# tf.Tensor(55.576515, shape=(), dtype=float32)
# tf.Tensor(75.77649, shape=(), dtype=float32)
# tf.Tensor(53.2552, shape=(), dtype=float32)
# tf.Tensor(83.8628, shape=(), dtype=float32)
# tf.Tensor(88.7241, shape=(), dtype=float32)
# tf.Tensor(45.3918, shape=(), dtype=float32)
# tf.Tensor(45.38083, shape=(), dtype=float32)
# tf.Tensor(55.457592, shape=(), dtype=float32)
# tf.Tensor(42.826023, shape=(), dtype=float32)
# tf.Tensor(72.03929, shape=(), dtype=float32)
# tf.Tensor(74.629814, shape=(), dtype=float32)
# tf.Tensor(58.06863, shape=(), dtype=float32)
# tf.Tensor(45.574764, shape=(), dtype=float32)
# tf.Tensor(64.824135, shape=(), dtype=float32)
# tf.Tensor(42.685226, shape=(), dtype=float32)
# tf.Tensor(23.148962, shape=(), dtype=float32)
# tf.Tensor(30.267006, shape=(), dtype=float32)
# tf.Tensor(41.440277, shape=(), dtype=float32)
# Train Epoch 2 Loss 65.4688
# Saving checkpoint for epoch 2 at trSfor3/cp.ckpt
# Valid prec 0.4594 recall 0.9293 AUC 0.9556, acc 0.8705
# Time taken for 1 epoch: 5924.18558382988 secs
#
# tf.Tensor(55.056736, shape=(), dtype=float32)
# tf.Tensor(44.23471, shape=(), dtype=float32)
# tf.Tensor(40.550045, shape=(), dtype=float32)
# tf.Tensor(61.23873, shape=(), dtype=float32)
# tf.Tensor(50.990974, shape=(), dtype=float32)
# tf.Tensor(49.975063, shape=(), dtype=float32)
# tf.Tensor(52.13459, shape=(), dtype=float32)
# tf.Tensor(74.86818, shape=(), dtype=float32)
# tf.Tensor(47.07922, shape=(), dtype=float32)
# tf.Tensor(44.313473, shape=(), dtype=float32)
# tf.Tensor(50.93074, shape=(), dtype=float32)
# tf.Tensor(46.600597, shape=(), dtype=float32)
# tf.Tensor(37.19545, shape=(), dtype=float32)
# tf.Tensor(62.38986, shape=(), dtype=float32)
# tf.Tensor(29.97706, shape=(), dtype=float32)
# tf.Tensor(30.222828, shape=(), dtype=float32)
# tf.Tensor(56.170822, shape=(), dtype=float32)
# tf.Tensor(30.065681, shape=(), dtype=float32)
# tf.Tensor(50.909576, shape=(), dtype=float32)
# tf.Tensor(52.479153, shape=(), dtype=float32)
# tf.Tensor(65.45062, shape=(), dtype=float32)
# tf.Tensor(17.030281, shape=(), dtype=float32)
# tf.Tensor(43.646614, shape=(), dtype=float32)
# tf.Tensor(38.839874, shape=(), dtype=float32)
# tf.Tensor(39.46929, shape=(), dtype=float32)
# tf.Tensor(60.742897, shape=(), dtype=float32)
# tf.Tensor(36.055725, shape=(), dtype=float32)
# tf.Tensor(29.555481, shape=(), dtype=float32)
# tf.Tensor(46.606728, shape=(), dtype=float32)
# tf.Tensor(58.897476, shape=(), dtype=float32)
# tf.Tensor(48.737556, shape=(), dtype=float32)
# tf.Tensor(26.639395, shape=(), dtype=float32)
# tf.Tensor(53.11174, shape=(), dtype=float32)
# tf.Tensor(15.542868, shape=(), dtype=float32)
# tf.Tensor(40.759903, shape=(), dtype=float32)
# tf.Tensor(60.907764, shape=(), dtype=float32)
# tf.Tensor(39.4273, shape=(), dtype=float32)
# tf.Tensor(28.482952, shape=(), dtype=float32)
# tf.Tensor(32.445797, shape=(), dtype=float32)
# tf.Tensor(46.113045, shape=(), dtype=float32)
# tf.Tensor(52.652054, shape=(), dtype=float32)
# tf.Tensor(27.734919, shape=(), dtype=float32)
# tf.Tensor(37.3127, shape=(), dtype=float32)
# tf.Tensor(52.210537, shape=(), dtype=float32)
# tf.Tensor(39.836727, shape=(), dtype=float32)
# tf.Tensor(28.196743, shape=(), dtype=float32)
# tf.Tensor(51.168594, shape=(), dtype=float32)
# tf.Tensor(44.830566, shape=(), dtype=float32)
# tf.Tensor(19.170536, shape=(), dtype=float32)
# tf.Tensor(47.029022, shape=(), dtype=float32)
# tf.Tensor(51.25396, shape=(), dtype=float32)
# tf.Tensor(49.568832, shape=(), dtype=float32)
# tf.Tensor(62.125774, shape=(), dtype=float32)
# tf.Tensor(40.390053, shape=(), dtype=float32)
# tf.Tensor(78.898575, shape=(), dtype=float32)
# tf.Tensor(32.24901, shape=(), dtype=float32)
# tf.Tensor(57.856895, shape=(), dtype=float32)
# tf.Tensor(41.235382, shape=(), dtype=float32)
# tf.Tensor(32.011852, shape=(), dtype=float32)
# tf.Tensor(45.02286, shape=(), dtype=float32)
# tf.Tensor(54.046066, shape=(), dtype=float32)
# tf.Tensor(49.633938, shape=(), dtype=float32)
# tf.Tensor(79.708626, shape=(), dtype=float32)
# tf.Tensor(76.18343, shape=(), dtype=float32)
# tf.Tensor(52.1137, shape=(), dtype=float32)
# tf.Tensor(48.12439, shape=(), dtype=float32)
# tf.Tensor(40.84839, shape=(), dtype=float32)
# tf.Tensor(69.76495, shape=(), dtype=float32)
# tf.Tensor(41.08516, shape=(), dtype=float32)
# tf.Tensor(75.476456, shape=(), dtype=float32)
# tf.Tensor(73.26233, shape=(), dtype=float32)
# tf.Tensor(74.33083, shape=(), dtype=float32)
# tf.Tensor(64.25406, shape=(), dtype=float32)
# tf.Tensor(54.09894, shape=(), dtype=float32)
# tf.Tensor(66.82156, shape=(), dtype=float32)
# tf.Tensor(35.1542, shape=(), dtype=float32)
# tf.Tensor(45.492622, shape=(), dtype=float32)
# tf.Tensor(71.44844, shape=(), dtype=float32)
# tf.Tensor(67.03488, shape=(), dtype=float32)
# tf.Tensor(62.626053, shape=(), dtype=float32)
# tf.Tensor(66.17337, shape=(), dtype=float32)
# tf.Tensor(58.902596, shape=(), dtype=float32)
# tf.Tensor(37.021404, shape=(), dtype=float32)
# tf.Tensor(68.83884, shape=(), dtype=float32)
# tf.Tensor(45.235474, shape=(), dtype=float32)
# tf.Tensor(28.62461, shape=(), dtype=float32)
# tf.Tensor(67.36366, shape=(), dtype=float32)
# tf.Tensor(57.292847, shape=(), dtype=float32)
# tf.Tensor(49.00815, shape=(), dtype=float32)
# tf.Tensor(45.599518, shape=(), dtype=float32)
# tf.Tensor(88.84305, shape=(), dtype=float32)
# tf.Tensor(46.239113, shape=(), dtype=float32)
# tf.Tensor(35.743668, shape=(), dtype=float32)
# tf.Tensor(55.879322, shape=(), dtype=float32)
# tf.Tensor(31.937946, shape=(), dtype=float32)
# tf.Tensor(52.51567, shape=(), dtype=float32)
# tf.Tensor(33.020107, shape=(), dtype=float32)
# tf.Tensor(44.16411, shape=(), dtype=float32)
# tf.Tensor(48.128754, shape=(), dtype=float32)
# tf.Tensor(52.982452, shape=(), dtype=float32)
# tf.Tensor(61.554832, shape=(), dtype=float32)
# tf.Tensor(63.7548, shape=(), dtype=float32)
# tf.Tensor(41.31311, shape=(), dtype=float32)
# tf.Tensor(48.6568, shape=(), dtype=float32)
# tf.Tensor(44.803333, shape=(), dtype=float32)
# tf.Tensor(49.367027, shape=(), dtype=float32)
# tf.Tensor(32.274784, shape=(), dtype=float32)
# tf.Tensor(32.506638, shape=(), dtype=float32)
# tf.Tensor(48.692368, shape=(), dtype=float32)
# tf.Tensor(31.577282, shape=(), dtype=float32)
# tf.Tensor(19.94106, shape=(), dtype=float32)
# tf.Tensor(44.63457, shape=(), dtype=float32)
# tf.Tensor(54.05229, shape=(), dtype=float32)
# tf.Tensor(33.919357, shape=(), dtype=float32)
# tf.Tensor(38.706802, shape=(), dtype=float32)
# tf.Tensor(32.267056, shape=(), dtype=float32)
# tf.Tensor(50.18932, shape=(), dtype=float32)
# tf.Tensor(58.065994, shape=(), dtype=float32)
# tf.Tensor(32.881817, shape=(), dtype=float32)
# tf.Tensor(24.38562, shape=(), dtype=float32)
# tf.Tensor(43.083405, shape=(), dtype=float32)
# tf.Tensor(28.180763, shape=(), dtype=float32)
# tf.Tensor(64.09917, shape=(), dtype=float32)
# tf.Tensor(39.120865, shape=(), dtype=float32)
# tf.Tensor(37.903915, shape=(), dtype=float32)
# tf.Tensor(25.860126, shape=(), dtype=float32)
# tf.Tensor(55.666786, shape=(), dtype=float32)
# tf.Tensor(43.88599, shape=(), dtype=float32)
# tf.Tensor(68.427765, shape=(), dtype=float32)
# tf.Tensor(65.41669, shape=(), dtype=float32)
# tf.Tensor(37.48432, shape=(), dtype=float32)
# tf.Tensor(32.716866, shape=(), dtype=float32)
# tf.Tensor(42.493156, shape=(), dtype=float32)
# tf.Tensor(50.803596, shape=(), dtype=float32)
# tf.Tensor(43.433334, shape=(), dtype=float32)
# tf.Tensor(48.292778, shape=(), dtype=float32)
# tf.Tensor(53.100983, shape=(), dtype=float32)
# tf.Tensor(28.225029, shape=(), dtype=float32)
# tf.Tensor(39.25055, shape=(), dtype=float32)
# tf.Tensor(66.5703, shape=(), dtype=float32)
# tf.Tensor(33.744694, shape=(), dtype=float32)
# tf.Tensor(21.851639, shape=(), dtype=float32)
# tf.Tensor(44.92872, shape=(), dtype=float32)
# tf.Tensor(48.49768, shape=(), dtype=float32)
# tf.Tensor(45.82375, shape=(), dtype=float32)
# tf.Tensor(20.983868, shape=(), dtype=float32)
# tf.Tensor(28.270214, shape=(), dtype=float32)
# tf.Tensor(46.66037, shape=(), dtype=float32)
# tf.Tensor(46.68309, shape=(), dtype=float32)
# tf.Tensor(53.203083, shape=(), dtype=float32)
# tf.Tensor(25.057838, shape=(), dtype=float32)
# tf.Tensor(29.919538, shape=(), dtype=float32)
# tf.Tensor(27.95079, shape=(), dtype=float32)
# tf.Tensor(54.86003, shape=(), dtype=float32)
# tf.Tensor(54.141705, shape=(), dtype=float32)
# tf.Tensor(28.208532, shape=(), dtype=float32)
# tf.Tensor(73.20712, shape=(), dtype=float32)
# tf.Tensor(49.186836, shape=(), dtype=float32)
# tf.Tensor(70.32239, shape=(), dtype=float32)
# tf.Tensor(27.429577, shape=(), dtype=float32)
# tf.Tensor(35.630646, shape=(), dtype=float32)
# tf.Tensor(56.10564, shape=(), dtype=float32)
# tf.Tensor(40.681023, shape=(), dtype=float32)
# tf.Tensor(36.168083, shape=(), dtype=float32)
# tf.Tensor(52.518288, shape=(), dtype=float32)
# tf.Tensor(62.566093, shape=(), dtype=float32)
# tf.Tensor(41.96251, shape=(), dtype=float32)
# tf.Tensor(33.22242, shape=(), dtype=float32)
# tf.Tensor(41.479874, shape=(), dtype=float32)
# tf.Tensor(52.71007, shape=(), dtype=float32)
# tf.Tensor(61.945267, shape=(), dtype=float32)
# tf.Tensor(67.745476, shape=(), dtype=float32)

# %%
# test

precFunc.reset_states()
recallFunc.reset_states()
AUCFunc.reset_states()
accFunc.reset_states()

encoder.load_weights(checkpoint_dir)
print("weights loaded from the epoch:", bestEpoch)
if not args._test:
    for tf1, tf2, tf3, tf4, tf5, tf6, tf7, tf8, tf9, tf10, tf11, tf12 in itertools.zip_longest(test_tf1, test_tf2, test_tf3, test_tf4, test_tf5, test_tf6,
                                     test_tf7, test_tf8, test_tf9, test_tf10, test_tf11, test_tf12):
        if tf1:
            test_step(tf1[0], tf1[1], 0)
        if tf2:
            test_step(tf2[0], tf2[1], 1)
        if tf3:
            test_step(tf3[0], tf3[1], 2)
        if tf4:
            test_step(tf4[0], tf4[1], 3)
        if tf5:
            test_step(tf5[0], tf5[1], 4)
        if tf6:
            test_step(tf6[0], tf6[1], 5)
        if tf7:
            test_step(tf7[0], tf7[1], 6)
        if tf8:
            test_step(tf8[0], tf8[1], 7)
        if tf9:
            test_step(tf9[0], tf9[1], 8)
        if tf10:
            test_step(tf10[0], tf10[1], 9)
        if tf11:
            test_step(tf11[0], tf11[1], 10)
        if tf12:
            test_step(tf12[0], tf12[1], 11)

    print('Test prec {:.4f} recall {:.4f} AUC {:.4f}, acc {:.4f}'.format(precFunc.result(), recallFunc.result(),
                                                                     AUCFunc.result(), accFunc.result()))

TC.on_train_end('_')

if not args.pickle_load:
    pickle.dump((embeddings_, dicC2I), open(args.current_num+"saved_emb.pkl", "wb"))
